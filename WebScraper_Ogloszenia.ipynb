# %% [markdown]
# #Importing packages

# %%
from bs4 import BeautifulSoup
from bs4 import ResultSet
import numpy as np
import pandas as pd
import requests
import re
import matplotlib.pyplot as plt
from scipy import stats

# %% [markdown]
# # Creating necesserary variables and functions

# %%
# A dictionary consisting of links from which the data would be gathered
urls = {
    'ogloszenia_wtórny': 'https://ogloszenia.trojmiasto.pl/nieruchomosci-rynek-wtorny/f1i,1_2_3,ri,1_,wi,100_200_230_250_260_220_240_210,xi,1900_.html',
    'ogloszenia_pierwotny': 'https://ogloszenia.trojmiasto.pl/nieruchomosci-rynek-pierwotny/f1i,1_2_3,ri,1_,wi,100_200_230_250_260_220_240_210,xi,1900_.html'
}

# %%
# Taking data from the main page and returning Sets of values for each attribute
def take_data_from_main(response):
  soup = BeautifulSoup(response.content, 'html.parser')
  title_list = soup.find_all(class_ ='list__item__content__title__name link')
  district_list = soup.select('p[class="list__item__content__subtitle"]')
  area_list = soup.select('li[class = "list__item__details__icons__element details--icons--element--powierzchnia"] p[class = "list__item__details__icons__element__desc"]')
  number_of_rooms_list = soup.select('li[class = "list__item__details__icons__element details--icons--element--l_pokoi"] p[class = "list__item__details__icons__element__desc"]')
  year_of_creation_list = soup.select('li[class = "list__item__details__icons__element details--icons--element--rok_budowy"] p[class = "list__item__details__icons__element__desc"]')
  price_list = soup.select('p[class = "list__item__details__info details--info--price"]')
  href_list = soup.select('a[class="list__item__content__title__name link"]')
  return title_list, district_list, area_list, number_of_rooms_list, year_of_creation_list, price_list, href_list

# Diving into the page of an individual advertisement and returning Sets of values for each attribute which was not shown on a main page
def take_data_from_individual(link):
  soup_for_specific_advertisement = BeautifulSoup(requests.get(link).content, 'html.parser')
  type_of_building = soup_for_specific_advertisement.select('div[class="xogField xogField--rodzaj_nieruchomosci"] span[class="xogField__value"]')[0].get_text().strip()
  additional_list = soup_for_specific_advertisement.select('li[class="oglFieldList__item"] b')

  # Adding a try clause because not every offer has an information of the floor (Not given or an offer is a house)
  try:
    floor = soup_for_specific_advertisement.select('a[class="xogField xogField--pietro xogField--withIcon"] span[class="xogField__value xogField__value--big"]')[0].get_text().strip()
  except:
    floor = "nan"
  return type_of_building, additional_list, floor

# %% [markdown]
# # Searching through the content of the page to gather necessary data such as:
# - title
# - area of the estate
# - number of rooms
# - district and street where estate is placed
# - year of creation

# %% [markdown]
# # Gathering data from the secondary market

# %%
#Initializing a list which would save records with advertisements data
data = []

#Searching data for secondary market (rynek wtórny)
url = urls['ogloszenia_wtórny']


"""
Iterating through each page and gathering necessary data such as:
- title
- district
- area
- number of rooms
- year of creation
- price in PLN (for m2)
- link of individual adv (to dive further)

"""
for page in range(0,150):
    print("Page number: " + str(page))
    response = requests.get(url, params={'strona': f"{page}"})
    print(response)
    if response.ok :

        # Using previously defined function for taking data from a main page
        title_list, district_list, area_list, number_of_rooms_list, year_of_creation_list, price_list, href_list = take_data_from_main(response)

        print(len(title_list))

        # Iterating through lists to create separate records
        for element in range(len(title_list)):
            try:
              price = price_list[element].get_text().replace(" ", "").rstrip("zł/m2")
            except:
              continue
            tytul = title_list[element].get_text().strip().replace("=", "")
            district = district_list[element].get_text().strip()
            powierzchnia = area_list[element].get_text().strip().rstrip(" m2")
            number_of_rooms = number_of_rooms_list[element].get_text().strip()
            year_of_creation = year_of_creation_list[element].get_text().strip()
            price = price_list[element].get_text().replace(" ", "").rstrip("zł/m2")
            href = href_list[element]
            link = href['href']
            type_of_building, additional_list, floor = take_data_from_individual(link)

            #Converting a Set of values into a list of strings
            additional_list_str = []
            find_string = lambda x : 1 if x.lower() in additional_list_str else 0
            for item in range(len(additional_list)):
              additional_list_str.append(additional_list[item].get_text().strip().lower())

            # Using lambda function to check if an asset for a buyer is in the offer
            garage = find_string('Garaż')
            balcony = find_string('Balkon')
            internet = find_string('Internet')
            parking = find_string('Miejsce Parkingowe')
            elevator = find_string('Winda')
            terrace = find_string('Taras')
            basement = find_string('Piwnica')
            garden = find_string('Ogródek')
            #print("Garage: " + str(garage) + " Balcony: " + str(balcony) + " Internet: " + str(internet) + " Parking: " + str(parking) + " Elevator: " + str(elevator) + " Terrace: " + str(terrace) + " Basement: " + str(basement))

            # Creating a record for a specific offer and adding it to a list
            print(additional_list_str)
            record = f"{tytul}={district}={powierzchnia}={number_of_rooms}={year_of_creation}={price}={type_of_building}={garage}={balcony}={internet}={parking}={elevator}={floor}={terrace}={basement}={garden}=secondary"
            data.append(record)
# Out:
# Page number: 0
# <Response [200]>
# 30
# ['balkon', 'garaż', 'winda', 'taras', 'piwnica', 'kuchnia']
# ['winda', 'ogródek', 'woda', 'piwnica', 'miejsce parkingowe']
# ['gaz', 'woda', 'kanalizacja', 'piwnica', 'miejsce parkingowe', 'internet', 'kuchnia', 'kablówka', 'światłowód', 'rowerownia']
# []
# []
# ['balkon', 'garaż', 'winda', 'taras', 'woda', 'kanalizacja', 'siła', 'piwnica', 'miejsce parkingowe', 'internet', 'kuchnia', 'aneks kuchenny', 'kablówka', 'podjazd dla niepełnosprawnych', 'światłowód', 'ochrona', 'komórka lokatorska', 'rowerownia', 'osiedle zamknięte']
# ['balkon', 'piwnica', 'miejsce parkingowe', 'kuchnia']
# ['taras', 'siła', 'miejsce parkingowe', 'internet']
# ['winda', 'ogródek', 'miejsce parkingowe', 'internet', 'aneks kuchenny', 'osiedle zamknięte']
# ['winda', 'taras', 'siła', 'miejsce parkingowe', 'internet', 'aneks kuchenny']
# []
# ['garaż', 'winda', 'aneks kuchenny']
# []
# []
# ['balkon', 'gaz', 'woda', 'kanalizacja', 'miejsce parkingowe', 'internet', 'kuchnia', 'kablówka', 'komórka lokatorska']
# ['balkon', 'winda', 'woda', 'kanalizacja', 'piwnica', 'miejsce parkingowe', 'internet']
# ['balkon', 'winda', 'gaz', 'woda', 'kanalizacja', 'piwnica', 'miejsce parkingowe', 'internet']
# ['balkon', 'winda', 'woda', 'kanalizacja', 'piwnica', 'miejsce parkingowe', 'internet']
# ['winda']
# ['balkon', 'woda', 'kanalizacja', 'piwnica', 'internet', 'kuchnia', 'kablówka', 'światłowód']
# ['woda', 'kanalizacja', 'piwnica', 'internet', 'kuchnia', 'kablówka', 'światłowód']
# ['winda', 'woda', 'kanalizacja', 'piwnica', 'internet', 'aneks kuchenny', 'kablówka', 'światłowód']
# ['balkon', 'winda', 'woda', 'kanalizacja', 'piwnica', 'internet', 'kuchnia', 'kablówka', 'światłowód']
# ['garaż', 'aneks kuchenny']
# ['balkon', 'garaż', 'ogródek', 'woda', 'kanalizacja', 'piwnica', 'miejsce parkingowe']
# ['balkon', 'woda', 'kanalizacja', 'siła', 'miejsce parkingowe', 'internet', 'aneks kuchenny', 'dwupoziomowe', 'kablówka', 'komórka lokatorska', 'osiedle zamknięte']
# []
# []
# ['balkon', 'winda', 'miejsce parkingowe', 'komórka lokatorska']
# ['balkon', 'winda', 'miejsce parkingowe', 'komórka lokatorska']
# Page number: 1
# <Response [200]>
# 30
# ['balkon', 'piwnica']
# ['balkon', 'winda']
# ['balkon', 'piwnica']
# ['garaż', 'ogródek', 'miejsce parkingowe']
# []
# ['winda', 'miejsce parkingowe']
# ['winda', 'miejsce parkingowe']
# ['winda', 'miejsce parkingowe']
# ['gaz', 'woda', 'kanalizacja', 'piwnica']
# ['woda', 'kanalizacja', 'piwnica', 'internet']
# ['ogródek', 'woda']
# ['balkon', 'garaż', 'ogródek', 'piwnica', 'miejsce parkingowe']
# ['balkon', 'woda', 'piwnica']
# ['balkon', 'winda', 'woda', 'kanalizacja', 'piwnica', 'internet']
# ['winda']
# ['garaż', 'ogródek', 'gaz', 'woda', 'kanalizacja', 'piwnica', 'miejsce parkingowe', 'internet']
# ['garaż', 'winda', 'aneks kuchenny']
# ['kuchnia']
# ['gaz', 'woda', 'kanalizacja', 'piwnica', 'internet']
# ['ogródek', 'siła', 'miejsce parkingowe', 'komórka lokatorska']
# ['garaż', 'winda', 'aneks kuchenny']
# ['balkon', 'winda', 'woda', 'kanalizacja', 'piwnica', 'miejsce parkingowe', 'internet']
# ['piwnica', 'miejsce parkingowe', 'internet', 'kuchnia']
# []
# ['balkon', 'garaż', 'miejsce parkingowe']
# ['balkon', 'piwnica']
# ['balkon', 'piwnica', 'miejsce parkingowe', 'internet', 'kuchnia']
# ['balkon', 'piwnica', 'miejsce parkingowe', 'internet', 'kuchnia']
# []
# ['balkon', 'garaż', 'winda', 'piwnica', 'miejsce parkingowe', 'internet', 'kuchnia']
# Page number: 2
# <Response [200]>
# 30
# ['balkon', 'garaż', 'taras', 'ogródek', 'gaz', 'woda', 'kanalizacja', 'siła', 'piwnica']
# []
# ['garaż', 'kuchnia']
# []
# ['balkon', 'winda', 'gaz', 'piwnica', 'kuchnia']
# ['balkon', 'winda', 'gaz', 'internet', 'kablówka', 'komórka lokatorska']
# ['ogródek', 'piwnica', 'miejsce parkingowe']
# ['balkon', 'garaż', 'ogródek', 'miejsce parkingowe']
# ['miejsce parkingowe', 'internet', 'kuchnia']
# ['balkon', 'gaz', 'siła', 'piwnica', 'kuchnia']
# ['piwnica', 'miejsce parkingowe', 'internet', 'kuchnia']
# []
# ['piwnica']
# ['balkon', 'garaż', 'woda', 'kanalizacja', 'piwnica', 'internet', 'kuchnia', 'kablówka']
# ['piwnica']
# ['balkon', 'piwnica', 'miejsce parkingowe']
# ['gaz', 'woda', 'kanalizacja', 'piwnica', 'miejsce parkingowe', 'internet']
# ['garaż', 'winda']
# ['garaż', 'winda', 'aneks kuchenny']
# ['balkon']
# ['balkon', 'piwnica', 'miejsce parkingowe', 'internet', 'kuchnia', 'kablówka', 'światłowód', 'rowerownia']
# ['loggia', 'piwnica']
# ['balkon', 'winda', 'loggia', 'woda', 'siła', 'miejsce parkingowe', 'internet', 'kuchnia', 'aneks kuchenny', 'kablówka', 'komórka lokatorska']
# ['balkon', 'winda', 'taras', 'piwnica', 'miejsce parkingowe', 'aneks kuchenny']
# ['balkon', 'piwnica', 'miejsce parkingowe', 'kuchnia']
# ['garaż', 'winda', 'kuchnia']
# ['piwnica', 'kuchnia', 'rowerownia']
# ['balkon', 'winda', 'woda', 'kanalizacja', 'miejsce parkingowe', 'internet']
# ['balkon', 'garaż', 'piwnica', 'internet', 'aneks kuchenny', 'kablówka']
# ['balkon', 'winda', 'woda', 'kanalizacja', 'miejsce parkingowe']
# Page number: 3
# <Response [200]>
# 30
# ['garaż', 'ogródek', 'gaz', 'woda', 'kanalizacja', 'siła', 'internet', 'aneks kuchenny', 'kablówka', 'podjazd dla niepełnosprawnych', 'światłowód', 'osiedle zamknięte']
# ['balkon', 'garaż', 'ogródek', 'gaz', 'kanalizacja', 'siła', 'piwnica', 'miejsce parkingowe', 'internet', 'kuchnia', 'kablówka', 'rowerownia']
# ['balkon', 'winda', 'kuchnia', 'komórka lokatorska']
# ['balkon', 'winda', 'piwnica', 'miejsce parkingowe', 'internet', 'kuchnia']
# ['balkon', 'piwnica', 'miejsce parkingowe']
# ['balkon', 'winda', 'piwnica', 'internet', 'kuchnia']
# ['siła', 'internet']
# ['piwnica', 'kuchnia']
# ['balkon', 'winda', 'piwnica', 'miejsce parkingowe', 'kuchnia']
# ['garaż', 'winda', 'aneks kuchenny']
# ['balkon', 'woda', 'kanalizacja', 'miejsce parkingowe', 'internet']
# []
# ['balkon', 'garaż', 'piwnica', 'miejsce parkingowe']
# ['balkon', 'garaż', 'woda', 'miejsce parkingowe', 'internet']
# ['balkon', 'winda', 'piwnica', 'aneks kuchenny', 'ochrona']
# []
# ['balkon', 'winda', 'woda', 'kanalizacja', 'siła', 'miejsce parkingowe', 'internet', 'kuchnia', 'aneks kuchenny', 'kablówka', 'światłowód', 'komórka lokatorska', 'osiedle zamknięte']
# ['balkon', 'woda', 'kanalizacja', 'miejsce parkingowe', 'internet', 'kuchnia', 'aneks kuchenny', 'kablówka', 'światłowód', 'komórka lokatorska', 'osiedle zamknięte']
# []
# []
# []
# []
# ['garaż', 'ogródek', 'piwnica', 'miejsce parkingowe']
# ['balkon', 'piwnica']
# []
# ['balkon', 'piwnica']
# ['balkon', 'winda', 'woda', 'piwnica', 'miejsce parkingowe', 'internet']
# ['balkon', 'woda', 'kanalizacja', 'piwnica']
# ['balkon', 'gaz', 'woda', 'kanalizacja', 'piwnica', 'internet']
# ['balkon', 'piwnica', 'kuchnia']
# Page number: 4
# <Response [200]>
# 30
# ['balkon', 'garaż', 'gaz', 'woda', 'kanalizacja', 'piwnica', 'miejsce parkingowe', 'internet']
# ['balkon', 'piwnica', 'dwupoziomowe']
# ['piwnica', 'dwupoziomowe']
# ['gaz', 'woda', 'kanalizacja', 'piwnica', 'miejsce parkingowe']
# ['balkon', 'garaż', 'ogródek', 'piwnica', 'miejsce parkingowe']
# []
# ['balkon', 'winda', 'miejsce parkingowe']
# ['garaż', 'kuchnia']
# ['balkon', 'winda', 'piwnica', 'miejsce parkingowe']
# ['balkon', 'winda', 'gaz', 'woda', 'kanalizacja', 'siła', 'miejsce parkingowe', 'internet', 'kuchnia', 'aneks kuchenny', 'dwupoziomowe', 'kablówka', 'antresola', 'światłowód', 'komórka lokatorska', 'rowerownia', 'osiedle zamknięte']
# ['garaż', 'piwnica', 'kuchnia', 'dwupoziomowe']
# ['garaż', 'taras', 'ogródek', 'gaz', 'woda', 'kanalizacja', 'miejsce parkingowe', 'internet', 'światłowód']
# ['balkon', 'winda', 'woda', 'miejsce parkingowe', 'internet']
# ['piwnica']
# ['winda']
# ['loggia']
# ['balkon', 'garaż', 'ogródek', 'piwnica', 'miejsce parkingowe']
# ['balkon', 'garaż', 'winda', 'taras', 'woda', 'kanalizacja', 'siła', 'miejsce parkingowe', 'internet', 'kuchnia', 'aneks kuchenny', 'kablówka', 'światłowód', 'komórka lokatorska']
# ['winda', 'taras', 'miejsce parkingowe', 'aneks kuchenny', 'dwupoziomowe', 'antresola', 'komórka lokatorska']
# ['garaż', 'winda', 'ogródek', 'woda', 'kanalizacja', 'siła', 'piwnica', 'miejsce parkingowe', 'internet', 'kuchnia', 'aneks kuchenny', 'światłowód', 'komórka lokatorska', 'rowerownia', 'osiedle zamknięte']
# []
# ['balkon', 'piwnica', 'kuchnia']
# ['gaz', 'siła', 'miejsce parkingowe', 'internet']
# ['garaż', 'gaz', 'siła', 'miejsce parkingowe', 'internet']
# ['garaż', 'winda', 'ogródek', 'piwnica', 'internet', 'aneks kuchenny', 'kablówka']
# ['balkon', 'garaż', 'winda', 'woda', 'kanalizacja', 'piwnica', 'internet', 'aneks kuchenny', 'kablówka']
# ['balkon', 'piwnica', 'aneks kuchenny']
# ['piwnica']
# ['woda', 'piwnica', 'miejsce parkingowe']
# ['balkon', 'winda', 'ogródek', 'miejsce parkingowe']
# Page number: 5
# <Response [200]>
# 30
# ['balkon', 'winda', 'miejsce parkingowe']
# []
# ['winda', 'woda', 'piwnica']
# ['balkon', 'piwnica']
# []
# ['balkon', 'winda', 'gaz', 'woda', 'kanalizacja', 'internet']
# ['winda', 'woda', 'miejsce parkingowe', 'internet']
# ['piwnica']
# ['balkon', 'piwnica', 'miejsce parkingowe']
# []
# ['balkon', 'gaz', 'woda', 'kanalizacja', 'piwnica', 'internet']
# []
# ['gaz']
# ['balkon', 'winda', 'piwnica', 'miejsce parkingowe']
# []
# ['winda', 'ogródek', 'miejsce parkingowe']
# ['gaz', 'woda', 'kanalizacja', 'piwnica', 'miejsce parkingowe', 'internet']
# []
# ['winda', 'miejsce parkingowe']
# ['balkon', 'garaż', 'piwnica', 'miejsce parkingowe']
# []
# ['balkon', 'garaż', 'ogródek', 'piwnica', 'miejsce parkingowe']
# ['winda']
# ['winda', 'woda', 'piwnica']
# ['balkon', 'piwnica']
# ['woda', 'kanalizacja', 'piwnica', 'internet']
# ['balkon']
# ['balkon', 'winda', 'woda']
# ['balkon', 'winda', 'woda', 'kanalizacja', 'miejsce parkingowe', 'internet']
# ['woda', 'internet']
# Page number: 6
# <Response [200]>
# 30
# ['winda', 'miejsce parkingowe']
# ['winda', 'woda', 'piwnica', 'miejsce parkingowe', 'internet']
# ['balkon', 'woda']
# ['balkon', 'piwnica']
# ['balkon', 'piwnica']
# ['balkon', 'miejsce parkingowe']
# ['ogródek', 'miejsce parkingowe']
# ['balkon']
# ['balkon', 'garaż', 'winda', 'woda', 'kanalizacja', 'miejsce parkingowe', 'internet', 'dwupoziomowe']
# []
# ['piwnica']
# []
# ['balkon', 'winda', 'piwnica']
# []
# ['piwnica', 'internet', 'kuchnia']
# ['balkon', 'garaż', 'winda', 'piwnica', 'miejsce parkingowe', 'aneks kuchenny', 'dwupoziomowe', 'podjazd dla niepełnosprawnych', 'rowerownia']
# ['balkon', 'winda']
# ['balkon', 'gaz', 'woda', 'kanalizacja', 'siła', 'miejsce parkingowe', 'internet', 'kablówka']
# ['winda', 'gaz', 'woda', 'kanalizacja', 'internet']
# ['balkon', 'gaz', 'woda', 'kanalizacja', 'miejsce parkingowe', 'internet']
# ['balkon', 'winda', 'gaz', 'woda', 'miejsce parkingowe', 'internet']
# ['garaż', 'ogródek', 'piwnica', 'miejsce parkingowe']
# ['balkon', 'garaż', 'piwnica', 'miejsce parkingowe']
# ['balkon', 'garaż', 'winda', 'woda', 'kanalizacja', 'piwnica', 'miejsce parkingowe', 'internet']
# ['balkon', 'winda', 'woda', 'kanalizacja', 'miejsce parkingowe', 'internet', 'aneks kuchenny', 'kablówka', 'światłowód', 'komórka lokatorska', 'rowerownia']
# ['balkon', 'garaż', 'winda', 'woda', 'kanalizacja', 'miejsce parkingowe', 'internet', 'kuchnia', 'aneks kuchenny', 'kablówka', 'podjazd dla niepełnosprawnych', 'światłowód', 'komórka lokatorska', 'rowerownia', 'osiedle zamknięte']
# ['balkon', 'winda', 'woda', 'kanalizacja', 'siła', 'miejsce parkingowe', 'internet', 'aneks kuchenny', 'kablówka', 'recepcja', 'osiedle zamknięte']
# ['garaż', 'winda', 'woda', 'kanalizacja', 'miejsce parkingowe', 'internet']
# ['winda', 'loggia']
# ['balkon', 'winda']
# Page number: 7
# <Response [200]>
# 30
# ['balkon', 'winda', 'woda', 'kanalizacja', 'piwnica', 'internet', 'kuchnia', 'kablówka']
# []
# ['balkon', 'woda', 'kanalizacja', 'piwnica', 'miejsce parkingowe', 'internet', 'kuchnia', 'kablówka', 'rowerownia']
# []
# ['ogródek', 'piwnica', 'miejsce parkingowe']
# ['balkon', 'miejsce parkingowe']
# ['piwnica']
# ['balkon', 'winda', 'gaz', 'woda', 'kanalizacja', 'internet', 'kuchnia', 'aneks kuchenny', 'kablówka', 'komórka lokatorska', 'rowerownia']
# ['winda']
# ['garaż', 'winda', 'taras', 'woda', 'kanalizacja', 'siła', 'miejsce parkingowe', 'internet', 'kuchnia', 'kablówka', 'światłowód', 'komórka lokatorska', 'rowerownia']
# ['balkon', 'piwnica', 'miejsce parkingowe', 'antresola', 'światłowód']
# []
# ['balkon', 'piwnica']
# ['balkon', 'winda', 'gaz', 'woda', 'piwnica', 'internet']
# ['balkon', 'winda', 'miejsce parkingowe']
# ['balkon', 'winda', 'miejsce parkingowe']
# ['balkon', 'piwnica', 'miejsce parkingowe']
# ['balkon', 'garaż', 'winda', 'miejsce parkingowe']
# ['gaz', 'woda', 'kanalizacja', 'piwnica', 'miejsce parkingowe']
# ['winda', 'miejsce parkingowe']
# ['woda', 'piwnica', 'internet']
# ['balkon', 'winda', 'piwnica']
# ['ogródek', 'piwnica', 'miejsce parkingowe']
# ['winda', 'miejsce parkingowe']
# ['balkon', 'piwnica']
# ['gaz', 'woda', 'piwnica', 'miejsce parkingowe', 'internet']
# ['balkon', 'winda', 'gaz', 'woda', 'kanalizacja', 'piwnica', 'internet', 'kuchnia', 'kablówka', 'światłowód']
# []
# ['balkon', 'garaż', 'winda', 'miejsce parkingowe']
# ['garaż', 'winda', 'woda', 'kanalizacja', 'miejsce parkingowe', 'internet']
# Page number: 8
# <Response [200]>
# 30
# ['balkon', 'miejsce parkingowe']
# []
# []
# ['balkon', 'winda', 'piwnica', 'kuchnia']
# []
# ['gaz', 'woda', 'piwnica', 'internet']
# ['balkon', 'winda', 'miejsce parkingowe']
# []
# ['balkon', 'winda', 'piwnica', 'miejsce parkingowe', 'internet']
# ['piwnica']
# []
# ['balkon', 'gaz', 'woda', 'kanalizacja', 'internet', 'aneks kuchenny', 'kablówka', 'komórka lokatorska']
# ['garaż', 'winda', 'taras', 'ogródek', 'woda', 'kanalizacja', 'siła', 'miejsce parkingowe', 'aneks kuchenny', 'kablówka', 'światłowód', 'ochrona', 'komórka lokatorska', 'rowerownia']
# ['garaż', 'winda', 'siła', 'internet', 'aneks kuchenny']
# []
# []
# ['balkon', 'winda', 'woda', 'kanalizacja', 'piwnica', 'miejsce parkingowe', 'internet']
# []
# []
# ['balkon', 'woda', 'kanalizacja', 'siła', 'piwnica', 'internet', 'aneks kuchenny']
# ['balkon', 'winda', 'gaz', 'woda', 'kanalizacja', 'piwnica', 'miejsce parkingowe', 'internet']
# []
# ['balkon', 'piwnica']
# ['balkon', 'winda', 'gaz', 'woda', 'kanalizacja', 'piwnica', 'internet', 'aneks kuchenny', 'kablówka', 'światłowód', 'rowerownia']
# ['balkon', 'piwnica', 'miejsce parkingowe']
# ['balkon', 'piwnica', 'miejsce parkingowe']
# ['balkon', 'garaż', 'woda', 'kanalizacja', 'siła', 'piwnica', 'internet', 'kuchnia', 'dwupoziomowe', 'kablówka']
# ['miejsce parkingowe']
# ['balkon', 'loggia', 'miejsce parkingowe', 'aneks kuchenny', 'recepcja', 'ochrona', 'komórka lokatorska', 'rowerownia']
# ['balkon', 'garaż', 'winda', 'woda', 'kanalizacja', 'siła', 'piwnica', 'miejsce parkingowe', 'internet', 'kuchnia', 'aneks kuchenny', 'kablówka', 'podjazd dla niepełnosprawnych', 'światłowód', 'ochrona', 'komórka lokatorska', 'rowerownia']
# Page number: 9
# <Response [200]>
# 30
# ['balkon', 'winda', 'ogródek', 'piwnica', 'miejsce parkingowe']
# ['balkon', 'piwnica']
# ['balkon', 'garaż', 'winda', 'kuchnia', 'aneks kuchenny', 'komórka lokatorska', 'osiedle zamknięte']
# ['gaz', 'woda', 'kanalizacja', 'piwnica', 'kuchnia']
# ['balkon', 'winda', 'woda', 'kanalizacja', 'piwnica', 'miejsce parkingowe', 'internet', 'kuchnia', 'komórka lokatorska', 'rowerownia']
# ['balkon', 'winda', 'taras', 'woda', 'kanalizacja', 'siła', 'piwnica', 'miejsce parkingowe', 'internet', 'kuchnia', 'aneks kuchenny', 'kablówka', 'podjazd dla niepełnosprawnych', 'światłowód', 'recepcja', 'ochrona', 'komórka lokatorska', 'osiedle zamknięte']
# ['balkon', 'winda', 'piwnica', 'miejsce parkingowe']
# ['balkon', 'winda', 'piwnica', 'miejsce parkingowe']
# ['balkon', 'garaż', 'winda', 'gaz', 'woda', 'miejsce parkingowe', 'internet']
# []
# []
# ['balkon', 'winda', 'gaz', 'woda', 'kanalizacja', 'siła', 'piwnica', 'internet', 'kuchnia']
# []
# []
# ['balkon', 'winda', 'miejsce parkingowe']
# ['balkon', 'winda', 'piwnica', 'miejsce parkingowe']
# ['balkon', 'miejsce parkingowe']
# ['piwnica']
# ['balkon', 'garaż', 'ogródek', 'miejsce parkingowe']
# ['balkon', 'gaz', 'woda', 'kanalizacja', 'piwnica']
# ['balkon', 'piwnica', 'miejsce parkingowe']
# ['ogródek', 'gaz', 'woda', 'kanalizacja', 'internet']
# ['balkon', 'winda', 'miejsce parkingowe']
# ['winda', 'gaz', 'woda', 'kanalizacja', 'piwnica', 'miejsce parkingowe']
# ['balkon', 'piwnica']
# ['balkon', 'gaz', 'woda', 'kanalizacja', 'piwnica']
# ['garaż', 'gaz', 'woda', 'kanalizacja', 'piwnica', 'miejsce parkingowe', 'internet']
# ['winda', 'woda', 'kanalizacja', 'piwnica']
# ['piwnica']
# []
# Page number: 10
# <Response [200]>
# 30
# ['balkon', 'winda', 'miejsce parkingowe']
# ['balkon', 'winda', 'piwnica']
# ['balkon', 'winda', 'woda', 'kanalizacja', 'piwnica', 'miejsce parkingowe']
# ['piwnica']
# ['balkon', 'winda', 'woda', 'kanalizacja', 'piwnica', 'miejsce parkingowe', 'internet']
# ['balkon', 'woda', 'internet']
# ['balkon', 'winda', 'miejsce parkingowe']
# ['balkon', 'winda', 'miejsce parkingowe']
# ['balkon', 'woda', 'miejsce parkingowe', 'internet']
# ['balkon', 'winda', 'miejsce parkingowe']
# ['balkon', 'winda', 'miejsce parkingowe']
# ['winda', 'ogródek', 'miejsce parkingowe']
# ['balkon', 'miejsce parkingowe']
# ['balkon', 'miejsce parkingowe']
# ['balkon', 'winda', 'woda', 'kanalizacja', 'miejsce parkingowe', 'internet']
# ['balkon', 'miejsce parkingowe']
# ['balkon', 'winda', 'miejsce parkingowe']
# ['balkon', 'winda', 'woda', 'kanalizacja', 'miejsce parkingowe', 'internet']
# ['balkon', 'miejsce parkingowe']
# ['winda', 'ogródek', 'miejsce parkingowe']
# ['balkon', 'winda', 'miejsce parkingowe']
# ['balkon', 'miejsce parkingowe']
# ['balkon', 'winda', 'woda', 'kanalizacja', 'miejsce parkingowe', 'internet']
# ['balkon', 'garaż', 'ogródek', 'woda', 'kanalizacja', 'miejsce parkingowe', 'internet']
# ['balkon', 'winda', 'miejsce parkingowe']
# ['balkon', 'winda', 'woda', 'kanalizacja', 'piwnica']
# ['balkon', 'piwnica']
# ['balkon', 'winda', 'piwnica']
# ['balkon', 'winda', 'miejsce parkingowe']
# ['balkon', 'woda', 'kanalizacja', 'piwnica', 'internet']
# Page number: 11
# <Response [200]>
# 30
# ['balkon', 'miejsce parkingowe']
# ['balkon', 'piwnica']
# ['balkon', 'winda', 'miejsce parkingowe']
# ['balkon', 'winda', 'miejsce parkingowe']
# ['balkon', 'miejsce parkingowe']
# ['balkon', 'garaż', 'winda', 'miejsce parkingowe']
# ['balkon', 'woda', 'kanalizacja', 'internet']
# ['balkon', 'winda', 'woda', 'kanalizacja', 'miejsce parkingowe']
# ['balkon', 'winda', 'woda', 'kanalizacja', 'miejsce parkingowe', 'internet']
# ['balkon', 'winda', 'woda', 'kanalizacja', 'miejsce parkingowe']
# ['balkon', 'garaż', 'winda', 'ogródek', 'woda', 'piwnica', 'miejsce parkingowe', 'internet']
# ['balkon', 'kanalizacja', 'piwnica', 'internet']
# ['balkon', 'miejsce parkingowe']
# ['balkon', 'piwnica', 'miejsce parkingowe']
# ['balkon', 'gaz', 'woda', 'kanalizacja', 'piwnica', 'internet']
# ['balkon', 'piwnica', 'miejsce parkingowe']
# ['balkon', 'piwnica']
# ['ogródek', 'miejsce parkingowe']
# ['piwnica']
# ['gaz', 'woda', 'kanalizacja', 'piwnica']
# ['piwnica', 'miejsce parkingowe']
# ['balkon']
# ['balkon', 'winda', 'piwnica', 'miejsce parkingowe']
# ['winda', 'ogródek', 'miejsce parkingowe']
# ['balkon', 'garaż', 'winda', 'miejsce parkingowe']
# ['garaż', 'ogródek', 'miejsce parkingowe']
# ['balkon', 'winda', 'gaz', 'woda', 'kanalizacja', 'piwnica', 'internet']
# ['gaz', 'woda', 'kanalizacja', 'piwnica']
# ['balkon', 'piwnica']
# ['winda', 'ogródek', 'woda', 'kanalizacja', 'miejsce parkingowe']
# Page number: 12
# <Response [200]>
# 30
# ['winda', 'ogródek', 'woda', 'kanalizacja', 'miejsce parkingowe', 'internet']
# ['gaz', 'woda', 'kanalizacja', 'piwnica', 'miejsce parkingowe', 'internet']
# ['winda', 'woda', 'kanalizacja']
# ['balkon', 'woda', 'kanalizacja', 'piwnica', 'internet']
# ['kuchnia']
# ['garaż', 'kuchnia']
# []
# ['garaż', 'winda', 'kuchnia']
# ['kuchnia']
# ['garaż', 'kuchnia']
# ['garaż', 'kuchnia']
# ['winda']
# ['garaż', 'kuchnia']
# ['aneks kuchenny']
# []
# ['winda', 'kuchnia']
# []
# ['garaż', 'kuchnia']
# ['garaż', 'kuchnia']
# ['miejsce parkingowe']
# ['winda', 'ogródek', 'piwnica', 'miejsce parkingowe']
# ['garaż', 'winda', 'aneks kuchenny']
# ['winda', 'woda', 'kanalizacja', 'miejsce parkingowe', 'internet']
# ['balkon', 'winda', 'kanalizacja', 'piwnica', 'internet']
# ['gaz', 'kanalizacja', 'piwnica', 'miejsce parkingowe', 'internet']
# ['balkon', 'garaż', 'miejsce parkingowe', 'internet']
# ['balkon', 'winda', 'woda', 'kanalizacja', 'miejsce parkingowe', 'internet']
# ['garaż', 'ogródek', 'gaz', 'woda', 'kanalizacja', 'piwnica', 'miejsce parkingowe', 'internet']
# ['winda', 'ogródek', 'gaz', 'woda', 'kanalizacja', 'miejsce parkingowe', 'internet', 'dwupoziomowe']
# ['balkon', 'winda', 'woda', 'kanalizacja', 'piwnica', 'miejsce parkingowe', 'internet']
# Page number: 13
# <Response [200]>
# 30
# ['ogródek', 'miejsce parkingowe']
# ['winda', 'woda', 'kanalizacja', 'piwnica', 'miejsce parkingowe', 'internet']
# ['garaż', 'ogródek', 'miejsce parkingowe']
# ['balkon', 'winda', 'woda', 'kanalizacja', 'miejsce parkingowe', 'internet']
# ['winda', 'ogródek', 'piwnica', 'miejsce parkingowe']
# ['winda', 'woda', 'kanalizacja', 'miejsce parkingowe', 'internet']
# ['balkon', 'loggia', 'woda', 'kanalizacja', 'siła', 'piwnica', 'internet', 'kuchnia', 'dwupoziomowe', 'kablówka', 'światłowód']
# ['balkon', 'winda', 'gaz', 'woda', 'kanalizacja', 'piwnica', 'internet', 'kuchnia', 'kablówka', 'światłowód']
# ['balkon', 'garaż', 'winda', 'aneks kuchenny']
# ['balkon', 'winda']
# ['balkon', 'winda', 'miejsce parkingowe']
# ['winda', 'gaz', 'woda', 'kanalizacja', 'miejsce parkingowe', 'internet']
# ['balkon', 'garaż', 'winda', 'woda', 'kanalizacja', 'piwnica', 'miejsce parkingowe', 'internet']
# ['ogródek', 'gaz', 'woda', 'kanalizacja', 'piwnica', 'internet']
# ['balkon', 'ogródek', 'piwnica']
# ['gaz', 'woda', 'kanalizacja', 'piwnica', 'miejsce parkingowe', 'kuchnia']
# ['ogródek', 'gaz', 'woda', 'kanalizacja', 'piwnica', 'internet']
# ['balkon', 'gaz', 'woda', 'kanalizacja', 'piwnica', 'miejsce parkingowe', 'internet']
# ['balkon', 'garaż', 'ogródek', 'piwnica', 'miejsce parkingowe']
# ['winda', 'loggia', 'miejsce parkingowe', 'recepcja', 'komórka lokatorska', 'rowerownia']
# ['balkon', 'piwnica']
# ['ogródek']
# ['gaz', 'woda', 'kanalizacja', 'piwnica']
# ['balkon', 'miejsce parkingowe']
# ['balkon', 'garaż', 'taras', 'ogródek', 'woda', 'kanalizacja', 'siła', 'piwnica', 'miejsce parkingowe', 'internet', 'aneks kuchenny', 'podjazd dla niepełnosprawnych', 'światłowód', 'komórka lokatorska']
# ['balkon', 'gaz', 'woda', 'kanalizacja', 'miejsce parkingowe', 'internet']
# ['winda', 'woda', 'kanalizacja', 'internet']
# ['balkon', 'gaz', 'woda', 'kanalizacja', 'piwnica', 'miejsce parkingowe']
# ['balkon', 'garaż', 'ogródek', 'piwnica', 'miejsce parkingowe']
# []
# Page number: 14
# <Response [200]>
# 30
# []
# ['winda']
# ['balkon', 'gaz', 'woda', 'kanalizacja', 'internet']
# ['balkon', 'piwnica', 'miejsce parkingowe']
# ['balkon', 'garaż', 'ogródek', 'woda', 'kanalizacja', 'piwnica', 'miejsce parkingowe']
# ['balkon', 'winda', 'miejsce parkingowe']
# ['balkon', 'winda']
# ['balkon', 'ogródek', 'piwnica']
# ['balkon', 'ogródek', 'piwnica']
# ['garaż', 'miejsce parkingowe']
# ['balkon', 'winda', 'ogródek', 'piwnica']
# ['balkon', 'ogródek', 'miejsce parkingowe']
# ['piwnica']
# ['ogródek', 'gaz', 'woda', 'kanalizacja', 'piwnica', 'miejsce parkingowe', 'internet']
# ['woda', 'miejsce parkingowe']
# ['balkon', 'ogródek', 'piwnica', 'miejsce parkingowe']
# ['balkon', 'winda', 'piwnica', 'miejsce parkingowe']
# ['balkon', 'winda', 'woda', 'kanalizacja']
# []
# []
# ['balkon', 'winda', 'miejsce parkingowe']
# ['balkon', 'piwnica']
# ['winda']
# ['balkon', 'garaż', 'miejsce parkingowe']
# []
# ['winda']
# ['balkon', 'gaz', 'woda', 'piwnica']
# ['balkon', 'winda', 'miejsce parkingowe']
# ['balkon']
# []
# Page number: 15
# <Response [200]>
# 30
# ['balkon', 'miejsce parkingowe']
# ['balkon']
# ['winda']
# ['balkon', 'winda', 'piwnica', 'miejsce parkingowe']
# ['balkon', 'winda', 'miejsce parkingowe']
# ['winda']
# ['winda']
# ['winda', 'ogródek', 'miejsce parkingowe']
# ['balkon', 'winda', 'woda', 'miejsce parkingowe', 'internet']
# ['winda', 'piwnica']
# []
# ['balkon', 'winda', 'woda', 'kanalizacja', 'miejsce parkingowe', 'internet']
# ['balkon', 'piwnica', 'miejsce parkingowe']
# ['balkon', 'winda', 'piwnica']
# []
# ['balkon', 'piwnica', 'miejsce parkingowe']
# ['woda', 'kanalizacja', 'piwnica']
# ['balkon', 'woda', 'internet']
# ['balkon', 'winda', 'woda', 'kanalizacja', 'miejsce parkingowe']
# ['piwnica']
# ['balkon', 'piwnica']
# ['woda', 'kanalizacja', 'siła', 'internet', 'aneks kuchenny', 'dwupoziomowe', 'kablówka']
# ['balkon', 'winda', 'piwnica']
# ['winda', 'gaz', 'woda', 'kanalizacja', 'piwnica', 'internet']
# ['gaz', 'woda', 'kanalizacja', 'piwnica']
# ['garaż', 'ogródek', 'miejsce parkingowe']
# ['winda']
# ['winda', 'piwnica']
# ['garaż', 'winda', 'taras', 'piwnica']
# ['ogródek', 'aneks kuchenny', 'komórka lokatorska']
# Page number: 16
# <Response [200]>
# 30
# ['balkon', 'garaż', 'winda', 'woda', 'kanalizacja', 'siła', 'miejsce parkingowe', 'internet', 'aneks kuchenny', 'kablówka', 'podjazd dla niepełnosprawnych', 'światłowód']
# ['balkon', 'garaż', 'taras', 'ogródek', 'gaz', 'woda', 'kanalizacja', 'siła', 'piwnica', 'internet', 'kuchnia', 'kablówka', 'światłowód']
# ['balkon', 'taras', 'loggia', 'ogródek', 'gaz', 'woda', 'kanalizacja', 'siła', 'piwnica', 'miejsce parkingowe', 'internet', 'kuchnia', 'kablówka', 'światłowód', 'komórka lokatorska', 'rowerownia']
# ['balkon', 'winda', 'woda', 'kanalizacja', 'miejsce parkingowe', 'internet', 'kuchnia', 'kablówka', 'światłowód', 'recepcja', 'ochrona']
# ['balkon', 'taras', 'loggia', 'ogródek', 'gaz', 'woda', 'kanalizacja', 'siła', 'piwnica', 'miejsce parkingowe', 'internet', 'kuchnia', 'kablówka', 'światłowód', 'komórka lokatorska', 'rowerownia']
# ['balkon', 'taras', 'loggia', 'ogródek', 'gaz', 'woda', 'kanalizacja', 'siła', 'piwnica', 'miejsce parkingowe', 'internet', 'kuchnia', 'kablówka', 'światłowód', 'komórka lokatorska', 'rowerownia']
# ['balkon', 'winda', 'piwnica', 'miejsce parkingowe', 'internet', 'kuchnia', 'kablówka', 'osiedle zamknięte']
# ['balkon', 'miejsce parkingowe', 'recepcja', 'ochrona', 'komórka lokatorska']
# []
# ['garaż', 'taras', 'gaz', 'siła', 'miejsce parkingowe']
# ['balkon', 'winda', 'gaz', 'woda', 'kanalizacja', 'siła', 'piwnica', 'internet', 'kuchnia', 'kablówka', 'światłowód']
# ['piwnica', 'miejsce parkingowe', 'kuchnia']
# ['balkon', 'woda', 'kanalizacja', 'piwnica', 'miejsce parkingowe', 'internet']
# ['piwnica']
# ['balkon', 'winda', 'woda', 'kanalizacja', 'piwnica', 'internet']
# ['gaz', 'woda', 'kanalizacja', 'piwnica', 'internet']
# ['balkon', 'woda', 'kanalizacja', 'siła', 'piwnica', 'miejsce parkingowe', 'internet', 'kuchnia', 'aneks kuchenny', 'dwupoziomowe', 'kablówka', 'światłowód', 'komórka lokatorska']
# ['winda', 'woda', 'kanalizacja', 'piwnica', 'miejsce parkingowe']
# ['winda', 'gaz', 'woda', 'kanalizacja', 'piwnica', 'miejsce parkingowe', 'internet']
# ['balkon', 'winda', 'gaz', 'woda', 'kanalizacja', 'piwnica']
# ['winda', 'miejsce parkingowe']
# ['balkon', 'winda', 'miejsce parkingowe']
# ['winda', 'woda', 'kanalizacja', 'piwnica', 'internet']
# ['piwnica']
# ['balkon', 'piwnica', 'miejsce parkingowe']
# ['balkon', 'winda', 'woda', 'kanalizacja', 'internet']
# ['woda', 'kanalizacja', 'miejsce parkingowe', 'internet']
# ['balkon']
# ['ogródek', 'gaz', 'woda', 'kanalizacja', 'piwnica', 'miejsce parkingowe', 'internet']
# ['balkon', 'winda', 'woda', 'kanalizacja', 'miejsce parkingowe', 'internet', 'dwupoziomowe']
# Page number: 17
# <Response [200]>
# 30
# ['balkon', 'gaz', 'woda', 'kanalizacja', 'piwnica']
# ['balkon', 'woda', 'kanalizacja', 'piwnica', 'miejsce parkingowe']
# ['gaz', 'woda', 'kanalizacja', 'piwnica', 'internet']
# ['piwnica']
# ['piwnica', 'miejsce parkingowe']
# ['woda', 'kanalizacja', 'piwnica', 'miejsce parkingowe', 'internet']
# ['gaz', 'woda', 'kanalizacja']
# ['balkon', 'winda', 'gaz', 'woda', 'kanalizacja', 'piwnica', 'miejsce parkingowe', 'internet']
# ['balkon', 'winda', 'miejsce parkingowe']
# ['garaż', 'ogródek', 'gaz', 'woda', 'kanalizacja', 'piwnica', 'miejsce parkingowe']
# ['piwnica']
# ['piwnica']
# ['gaz', 'woda', 'kanalizacja', 'piwnica', 'internet']
# ['miejsce parkingowe']
# ['gaz', 'woda', 'kanalizacja', 'piwnica', 'miejsce parkingowe', 'internet']
# ['balkon', 'winda', 'miejsce parkingowe']
# ['balkon', 'gaz', 'woda', 'kanalizacja', 'piwnica', 'miejsce parkingowe', 'internet']
# ['miejsce parkingowe']
# ['gaz', 'woda', 'kanalizacja', 'piwnica', 'miejsce parkingowe']
# ['balkon', 'winda', 'woda', 'internet']
# ['balkon', 'winda', 'woda', 'kanalizacja', 'miejsce parkingowe', 'internet']
# ['ogródek', 'gaz', 'woda', 'kanalizacja', 'piwnica', 'internet', 'dwupoziomowe']
# ['gaz', 'woda', 'kanalizacja', 'miejsce parkingowe']
# ['miejsce parkingowe']
# ['piwnica']
# ['garaż', 'miejsce parkingowe']
# ['balkon', 'winda', 'woda', 'kanalizacja', 'miejsce parkingowe', 'internet']
# ['piwnica']
# ['balkon', 'miejsce parkingowe']
# ['balkon', 'garaż', 'winda', 'miejsce parkingowe']
# Page number: 18
# <Response [200]>
# 30
# ['balkon', 'gaz', 'woda', 'kanalizacja', 'piwnica', 'internet']
# ['winda', 'woda', 'piwnica']
# ['piwnica', 'miejsce parkingowe']
# []
# ['piwnica']
# ['winda', 'piwnica', 'kuchnia']
# ['miejsce parkingowe']
# ['piwnica']
# ['balkon', 'winda', 'piwnica']
# ['ogródek', 'piwnica']
# ['balkon', 'winda', 'woda', 'kanalizacja', 'miejsce parkingowe', 'internet']
# ['balkon', 'winda', 'woda', 'kanalizacja', 'piwnica', 'miejsce parkingowe', 'internet']
# ['balkon', 'gaz', 'woda', 'kanalizacja', 'piwnica', 'miejsce parkingowe']
# ['ogródek', 'woda', 'piwnica', 'miejsce parkingowe']
# ['balkon', 'winda', 'miejsce parkingowe']
# ['balkon', 'piwnica']
# ['balkon', 'winda', 'miejsce parkingowe']
# ['balkon', 'winda', 'ogródek', 'miejsce parkingowe']
# ['piwnica']
# ['balkon', 'gaz', 'woda', 'kanalizacja', 'piwnica', 'internet']
# ['miejsce parkingowe']
# ['balkon', 'woda', 'kanalizacja', 'internet']
# ['ogródek', 'gaz', 'woda', 'kanalizacja', 'piwnica', 'miejsce parkingowe', 'internet']
# ['balkon', 'winda', 'miejsce parkingowe']
# ['miejsce parkingowe']
# ['ogródek', 'piwnica']
# ['balkon', 'winda', 'piwnica']
# ['balkon', 'winda', 'woda', 'kanalizacja', 'miejsce parkingowe', 'internet']
# ['balkon', 'winda', 'woda', 'kanalizacja', 'internet']
# ['balkon', 'ogródek', 'miejsce parkingowe']
# Page number: 19
# <Response [200]>
# 30
# ['ogródek', 'gaz', 'woda', 'kanalizacja', 'piwnica', 'internet']
# ['balkon', 'woda', 'piwnica']
# ['balkon', 'winda', 'piwnica']
# ['balkon', 'garaż', 'winda', 'woda', 'kanalizacja', 'miejsce parkingowe', 'internet']
# ['balkon', 'winda', 'woda', 'kanalizacja', 'piwnica', 'miejsce parkingowe', 'internet']
# ['balkon', 'winda', 'piwnica']
# ['balkon', 'winda', 'miejsce parkingowe']
# ['winda', 'ogródek', 'piwnica', 'internet']
# ['balkon', 'ogródek', 'piwnica']
# ['balkon', 'garaż', 'piwnica', 'miejsce parkingowe', 'internet', 'kuchnia']
# ['taras', 'piwnica', 'miejsce parkingowe', 'internet', 'kuchnia']
# []
# ['balkon', 'gaz', 'woda', 'kanalizacja', 'miejsce parkingowe', 'internet']
# ['gaz']
# []
# ['balkon', 'winda', 'piwnica', 'kuchnia']
# ['siła', 'internet']
# []
# ['balkon', 'winda', 'miejsce parkingowe', 'komórka lokatorska', 'osiedle zamknięte']
# ['garaż', 'taras', 'ogródek', 'gaz', 'woda', 'kanalizacja', 'siła', 'internet', 'kuchnia', 'dwupoziomowe', 'światłowód']
# ['garaż', 'winda', 'aneks kuchenny']
# ['balkon', 'piwnica', 'miejsce parkingowe', 'internet', 'kuchnia']
# ['woda', 'kanalizacja', 'piwnica', 'internet', 'aneks kuchenny', 'kablówka']
# ['balkon', 'woda', 'piwnica']
# ['winda', 'ogródek', 'miejsce parkingowe']
# ['piwnica']
# ['balkon', 'winda', 'piwnica', 'miejsce parkingowe']
# ['garaż', 'winda', 'recepcja', 'ochrona']
# []
# ['taras', 'ogródek', 'piwnica', 'internet', 'aneks kuchenny', 'kablówka', 'podjazd dla niepełnosprawnych', 'światłowód']
# Page number: 20
# <Response [200]>
# 30
# ['piwnica']
# ['ogródek', 'miejsce parkingowe']
# ['balkon', 'winda', 'woda', 'kanalizacja', 'miejsce parkingowe', 'internet']
# ['balkon', 'winda', 'woda', 'kanalizacja', 'miejsce parkingowe', 'internet']
# ['balkon', 'piwnica', 'kuchnia']
# []
# ['gaz', 'woda', 'piwnica', 'internet', 'kuchnia', 'kablówka']
# ['balkon', 'winda', 'gaz', 'woda', 'kanalizacja', 'kuchnia', 'podjazd dla niepełnosprawnych']
# ['garaż', 'ogródek', 'piwnica', 'miejsce parkingowe']
# ['woda', 'kanalizacja', 'piwnica']
# []
# ['piwnica', 'internet']
# ['garaż', 'ogródek', 'miejsce parkingowe']
# ['balkon', 'piwnica', 'miejsce parkingowe', 'kuchnia']
# ['balkon', 'winda', 'piwnica', 'miejsce parkingowe']
# ['balkon', 'piwnica', 'miejsce parkingowe']
# ['balkon', 'gaz', 'woda', 'kanalizacja', 'piwnica']
# ['gaz', 'woda', 'kanalizacja', 'piwnica']
# ['winda', 'ogródek', 'woda', 'miejsce parkingowe', 'internet']
# []
# ['gaz', 'woda', 'kanalizacja', 'piwnica', 'internet']
# ['piwnica']
# ['winda', 'woda']
# ['balkon', 'winda']
# ['piwnica']
# ['balkon', 'gaz', 'woda', 'kanalizacja', 'piwnica']
# ['balkon', 'winda', 'gaz', 'woda', 'kanalizacja', 'piwnica', 'internet']
# ['balkon', 'winda']
# ['balkon', 'winda', 'woda', 'kanalizacja', 'miejsce parkingowe', 'internet']
# ['piwnica', 'miejsce parkingowe']
# Page number: 21
# <Response [200]>
# 30
# ['winda', 'gaz', 'woda', 'piwnica', 'miejsce parkingowe']
# ['balkon', 'gaz', 'woda', 'piwnica', 'internet']
# ['balkon', 'piwnica']
# ['balkon', 'winda', 'miejsce parkingowe']
# ['balkon', 'gaz', 'woda', 'kanalizacja', 'piwnica', 'miejsce parkingowe', 'internet']
# ['piwnica']
# []
# ['balkon', 'winda', 'miejsce parkingowe']
# ['balkon', 'winda', 'woda', 'internet']
# ['balkon', 'winda', 'miejsce parkingowe']
# ['balkon', 'winda', 'miejsce parkingowe']
# ['balkon', 'winda', 'woda', 'kanalizacja', 'piwnica', 'miejsce parkingowe', 'internet']
# ['balkon', 'piwnica', 'miejsce parkingowe']
# ['balkon', 'gaz', 'woda', 'kanalizacja', 'piwnica', 'miejsce parkingowe', 'internet']
# ['balkon', 'winda', 'woda', 'kanalizacja', 'internet']
# ['balkon', 'miejsce parkingowe']
# []
# ['ogródek', 'woda', 'kanalizacja', 'siła', 'internet', 'kuchnia', 'aneks kuchenny', 'komórka lokatorska']
# ['ogródek', 'miejsce parkingowe']
# []
# ['balkon', 'winda', 'piwnica']
# ['balkon', 'winda', 'woda', 'kanalizacja', 'miejsce parkingowe', 'internet']
# []
# []
# ['gaz', 'woda', 'kanalizacja', 'siła', 'aneks kuchenny']
# ['balkon', 'piwnica']
# ['winda', 'ogródek', 'miejsce parkingowe']
# ['miejsce parkingowe']
# []
# []
# Page number: 22
# <Response [200]>
# 30
# []
# []
# ['balkon', 'winda', 'gaz', 'woda', 'kanalizacja', 'miejsce parkingowe', 'internet']
# ['ogródek']
# ['gaz', 'piwnica', 'internet', 'kuchnia', 'rowerownia']
# ['ogródek', 'woda', 'kanalizacja', 'miejsce parkingowe', 'internet']
# ['balkon', 'woda', 'kanalizacja', 'miejsce parkingowe', 'internet']
# ['balkon', 'woda', 'kanalizacja', 'siła', 'miejsce parkingowe', 'internet', 'kuchnia', 'kablówka', 'komórka lokatorska']
# ['balkon', 'woda', 'kanalizacja', 'miejsce parkingowe', 'internet']
# []
# ['balkon', 'ogródek', 'woda', 'kanalizacja', 'piwnica', 'miejsce parkingowe', 'internet', 'dwupoziomowe']
# ['garaż', 'ogródek', 'miejsce parkingowe']
# ['balkon', 'winda', 'piwnica', 'miejsce parkingowe']
# ['balkon', 'winda', 'woda', 'kanalizacja', 'internet']
# ['balkon', 'winda', 'woda', 'kanalizacja', 'miejsce parkingowe', 'internet']
# ['balkon', 'winda', 'miejsce parkingowe']
# ['balkon', 'gaz', 'woda', 'kanalizacja', 'piwnica', 'internet', 'dwupoziomowe']
# ['balkon', 'piwnica', 'miejsce parkingowe', 'internet', 'kuchnia', 'dwupoziomowe']
# ['balkon']
# ['balkon', 'miejsce parkingowe', 'internet', 'kuchnia']
# ['balkon', 'gaz', 'woda', 'kanalizacja', 'piwnica', 'internet', 'aneks kuchenny', 'kablówka', 'światłowód']
# ['balkon', 'winda', 'miejsce parkingowe', 'internet', 'aneks kuchenny', 'kablówka', 'podjazd dla niepełnosprawnych', 'światłowód', 'ochrona', 'komórka lokatorska', 'rowerownia', 'osiedle zamknięte']
# ['balkon', 'winda', 'gaz', 'woda', 'kanalizacja', 'piwnica', 'miejsce parkingowe', 'kuchnia']
# []
# ['balkon', 'winda', 'ogródek', 'woda', 'kanalizacja', 'miejsce parkingowe', 'internet']
# ['balkon', 'winda', 'woda', 'kanalizacja', 'miejsce parkingowe', 'internet']
# ['balkon', 'winda', 'miejsce parkingowe']
# ['balkon']
# ['balkon', 'winda', 'miejsce parkingowe']
# ['balkon', 'winda', 'piwnica', 'miejsce parkingowe']
# Page number: 23
# <Response [200]>
# 30
# ['balkon', 'piwnica']
# ['balkon', 'winda', 'woda', 'kanalizacja', 'siła', 'piwnica', 'miejsce parkingowe', 'internet', 'aneks kuchenny', 'podjazd dla niepełnosprawnych', 'światłowód']
# ['balkon', 'winda', 'woda', 'kanalizacja', 'piwnica', 'miejsce parkingowe', 'internet', 'aneks kuchenny', 'kablówka', 'światłowód', 'komórka lokatorska', 'osiedle zamknięte']
# ['garaż', 'taras', 'ogródek', 'gaz', 'woda', 'kanalizacja', 'internet', 'kuchnia', 'dwupoziomowe', 'osiedle zamknięte']
# ['piwnica', 'internet']
# ['balkon', 'woda', 'kanalizacja', 'internet']
# ['winda', 'ogródek', 'miejsce parkingowe']
# []
# ['winda', 'gaz', 'woda', 'kanalizacja', 'piwnica']
# ['balkon', 'winda', 'miejsce parkingowe']
# ['balkon', 'piwnica']
# ['gaz', 'woda', 'kanalizacja', 'internet']
# ['balkon', 'gaz', 'woda', 'kanalizacja', 'piwnica', 'internet']
# []
# []
# ['piwnica', 'miejsce parkingowe']
# []
# ['piwnica']
# []
# ['winda', 'ogródek']
# ['balkon', 'winda', 'woda', 'kanalizacja', 'miejsce parkingowe', 'internet']
# ['ogródek', 'miejsce parkingowe', 'internet', 'aneks kuchenny', 'kablówka', 'podjazd dla niepełnosprawnych', 'ochrona', 'komórka lokatorska', 'osiedle zamknięte']
# []
# []
# ['woda', 'kanalizacja', 'siła', 'piwnica', 'internet', 'aneks kuchenny', 'kablówka']
# []
# ['balkon', 'garaż', 'ogródek', 'gaz', 'woda', 'kanalizacja', 'piwnica', 'miejsce parkingowe', 'internet', 'kuchnia']
# ['balkon', 'gaz', 'woda', 'kanalizacja', 'piwnica', 'kuchnia', 'światłowód']
# ['balkon']
# ['balkon', 'winda', 'piwnica', 'miejsce parkingowe']
# Page number: 24
# <Response [200]>
# 30
# ['winda', 'taras', 'gaz', 'woda', 'piwnica', 'internet', 'kuchnia']
# ['garaż', 'ogródek', 'piwnica']
# ['balkon', 'piwnica']
# []
# ['balkon', 'woda', 'kanalizacja', 'miejsce parkingowe', 'internet']
# []
# ['balkon', 'ogródek', 'gaz', 'woda', 'kanalizacja', 'siła', 'piwnica', 'internet', 'kuchnia', 'kablówka', 'światłowód', 'rowerownia']
# ['balkon', 'ogródek', 'gaz', 'woda', 'kanalizacja', 'siła', 'piwnica', 'internet', 'kuchnia', 'kablówka', 'światłowód', 'rowerownia']
# []
# ['winda', 'ogródek', 'woda', 'kanalizacja', 'miejsce parkingowe', 'internet']
# ['winda', 'woda', 'kanalizacja', 'internet']
# []
# ['ogródek', 'gaz', 'woda', 'kanalizacja', 'piwnica', 'miejsce parkingowe']
# []
# ['winda']
# ['balkon', 'winda', 'piwnica']
# ['balkon', 'winda', 'woda', 'kanalizacja', 'miejsce parkingowe', 'internet']
# []
# ['balkon', 'winda', 'miejsce parkingowe', 'komórka lokatorska']
# []
# []
# ['balkon', 'garaż', 'winda', 'loggia', 'piwnica', 'miejsce parkingowe', 'kuchnia', 'aneks kuchenny', 'recepcja', 'ochrona', 'komórka lokatorska']
# ['balkon', 'winda', 'miejsce parkingowe', 'kuchnia', 'aneks kuchenny', 'ochrona', 'komórka lokatorska']
# []
# []
# []
# ['ogródek', 'miejsce parkingowe', 'komórka lokatorska']
# ['balkon', 'garaż', 'woda', 'kanalizacja', 'siła', 'internet', 'kuchnia', 'aneks kuchenny', 'kablówka', 'światłowód', 'komórka lokatorska', 'rowerownia', 'osiedle zamknięte']
# ['garaż', 'taras', 'woda', 'kanalizacja', 'piwnica', 'miejsce parkingowe', 'internet', 'kuchnia', 'kablówka', 'osiedle zamknięte']
# ['balkon', 'garaż', 'ogródek', 'miejsce parkingowe']
# Page number: 25
# <Response [200]>
# 30
# ['winda', 'woda', 'kanalizacja', 'siła', 'osiedle zamknięte']
# ['balkon', 'winda', 'miejsce parkingowe']
# ['balkon', 'siła', 'piwnica', 'internet', 'kuchnia']
# ['balkon', 'winda', 'miejsce parkingowe']
# ['balkon', 'winda', 'woda', 'kanalizacja', 'miejsce parkingowe', 'internet']
# ['balkon', 'winda', 'woda', 'kanalizacja', 'miejsce parkingowe', 'internet']
# []
# ['balkon', 'garaż', 'miejsce parkingowe']
# ['balkon', 'piwnica', 'miejsce parkingowe']
# ['winda', 'ogródek', 'piwnica', 'miejsce parkingowe']
# ['balkon', 'woda', 'internet']
# ['balkon', 'gaz', 'woda', 'piwnica', 'internet']
# []
# ['balkon', 'winda', 'woda', 'kanalizacja', 'miejsce parkingowe', 'internet']
# ['balkon', 'gaz', 'woda', 'kanalizacja', 'piwnica', 'miejsce parkingowe', 'internet']
# ['winda', 'woda', 'kanalizacja', 'internet']
# ['winda', 'woda', 'kanalizacja', 'internet']
# ['balkon', 'winda', 'woda', 'kanalizacja', 'miejsce parkingowe', 'internet']
# ['balkon', 'miejsce parkingowe', 'internet']
# ['balkon', 'winda']
# []
# ['balkon', 'winda', 'woda', 'piwnica', 'miejsce parkingowe', 'internet']
# ['balkon', 'winda', 'gaz', 'woda', 'kanalizacja', 'siła', 'miejsce parkingowe', 'kuchnia', 'aneks kuchenny', 'osiedle zamknięte']
# ['balkon', 'winda', 'woda', 'kanalizacja', 'internet', 'kuchnia', 'kablówka', 'komórka lokatorska', 'osiedle zamknięte']
# []
# []
# ['balkon', 'winda', 'siła', 'piwnica', 'internet', 'kuchnia']
# []
# ['balkon', 'woda', 'kanalizacja', 'siła', 'piwnica', 'miejsce parkingowe', 'internet', 'kuchnia', 'aneks kuchenny', 'kablówka', 'światłowód', 'komórka lokatorska', 'rowerownia']
# ['balkon', 'piwnica', 'miejsce parkingowe']
# Page number: 26
# <Response [200]>
# 30
# ['balkon', 'gaz', 'woda', 'kanalizacja', 'piwnica', 'miejsce parkingowe', 'internet']
# ['balkon', 'garaż']
# ['balkon', 'gaz', 'woda', 'kanalizacja', 'piwnica']
# ['garaż', 'winda']
# ['balkon', 'gaz', 'woda', 'kanalizacja', 'siła', 'piwnica', 'kuchnia']
# ['balkon', 'woda', 'kanalizacja', 'siła', 'miejsce parkingowe', 'internet', 'aneks kuchenny', 'kablówka', 'światłowód', 'ochrona', 'rowerownia', 'osiedle zamknięte']
# ['winda', 'miejsce parkingowe', 'internet']
# ['balkon', 'garaż', 'ogródek', 'gaz', 'woda', 'kanalizacja', 'piwnica', 'miejsce parkingowe']
# ['winda', 'woda', 'kanalizacja', 'piwnica', 'miejsce parkingowe', 'internet']
# ['balkon', 'winda', 'piwnica', 'miejsce parkingowe', 'internet', 'kuchnia']
# ['balkon', 'winda', 'piwnica']
# ['balkon', 'piwnica', 'miejsce parkingowe', 'internet', 'kuchnia', 'światłowód']
# ['balkon', 'garaż', 'taras', 'ogródek', 'gaz', 'woda', 'kanalizacja', 'siła', 'piwnica', 'miejsce parkingowe', 'internet', 'aneks kuchenny', 'kablówka']
# ['balkon', 'gaz', 'woda', 'kanalizacja', 'miejsce parkingowe']
# ['winda', 'woda', 'kanalizacja', 'miejsce parkingowe', 'internet']
# ['garaż', 'winda', 'miejsce parkingowe']
# []
# ['winda', 'ogródek', 'woda', 'kanalizacja', 'miejsce parkingowe', 'internet']
# ['balkon', 'garaż', 'ogródek', 'gaz', 'woda', 'kanalizacja', 'miejsce parkingowe', 'internet']
# ['balkon', 'winda']
# ['balkon', 'winda', 'piwnica', 'miejsce parkingowe']
# ['ogródek']
# ['balkon', 'winda', 'woda', 'kanalizacja', 'piwnica', 'miejsce parkingowe', 'internet', 'aneks kuchenny', 'kablówka', 'światłowód', 'osiedle zamknięte']
# ['balkon', 'winda', 'gaz', 'woda', 'kanalizacja', 'piwnica', 'internet']
# ['winda']
# ['taras', 'ogródek', 'woda', 'kanalizacja', 'piwnica', 'internet', 'aneks kuchenny', 'kablówka']
# ['piwnica', 'miejsce parkingowe']
# ['balkon', 'winda', 'gaz', 'woda', 'kanalizacja', 'piwnica', 'internet']
# []
# ['balkon', 'garaż', 'piwnica', 'miejsce parkingowe']
# Page number: 27
# <Response [200]>
# 30
# ['balkon', 'winda', 'piwnica']
# ['balkon', 'winda', 'piwnica', 'miejsce parkingowe']
# ['balkon', 'winda', 'miejsce parkingowe']
# ['balkon', 'garaż', 'ogródek', 'piwnica', 'miejsce parkingowe']
# ['ogródek', 'gaz', 'woda', 'kanalizacja', 'miejsce parkingowe', 'internet']
# ['balkon', 'winda', 'miejsce parkingowe', 'internet']
# ['balkon', 'piwnica', 'miejsce parkingowe', 'internet', 'kuchnia']
# ['balkon', 'piwnica']
# ['balkon', 'miejsce parkingowe']
# ['balkon', 'winda', 'miejsce parkingowe', 'internet', 'kuchnia']
# []
# []
# []
# ['winda', 'ogródek', 'miejsce parkingowe']
# ['ogródek', 'miejsce parkingowe']
# ['balkon', 'winda']
# ['balkon', 'piwnica']
# ['balkon', 'winda', 'piwnica']
# ['balkon', 'winda']
# ['garaż', 'winda', 'kuchnia']
# ['balkon', 'gaz', 'woda', 'kanalizacja', 'siła', 'piwnica', 'internet', 'kuchnia', 'rowerownia']
# []
# []
# []
# ['balkon', 'miejsce parkingowe', 'aneks kuchenny', 'komórka lokatorska', 'osiedle zamknięte']
# ['balkon', 'garaż', 'taras', 'ogródek', 'piwnica', 'miejsce parkingowe']
# ['kuchnia']
# ['balkon', 'miejsce parkingowe']
# ['winda', 'piwnica']
# ['balkon', 'garaż', 'winda', 'woda', 'kanalizacja', 'miejsce parkingowe', 'internet']
# Page number: 28
# <Response [200]>
# 30
# ['balkon', 'garaż', 'winda', 'woda', 'kanalizacja', 'miejsce parkingowe', 'internet']
# []
# ['balkon', 'piwnica']
# ['balkon', 'winda', 'piwnica']
# ['balkon']
# ['winda', 'miejsce parkingowe']
# ['balkon', 'piwnica', 'miejsce parkingowe', 'dwupoziomowe', 'osiedle zamknięte']
# ['balkon', 'garaż', 'ogródek', 'gaz', 'woda', 'kanalizacja', 'miejsce parkingowe', 'internet']
# ['gaz', 'woda', 'kanalizacja', 'piwnica', 'internet']
# ['piwnica']
# ['balkon', 'winda', 'piwnica', 'kuchnia', 'podjazd dla niepełnosprawnych', 'komórka lokatorska']
# ['taras', 'internet', 'kuchnia', 'kablówka']
# ['balkon', 'winda', 'woda', 'kanalizacja', 'internet']
# ['winda', 'piwnica', 'miejsce parkingowe']
# ['balkon', 'woda', 'kanalizacja', 'siła', 'miejsce parkingowe', 'internet', 'aneks kuchenny', 'kablówka', 'komórka lokatorska', 'osiedle zamknięte']
# ['woda', 'piwnica', 'internet', 'kuchnia', 'kablówka']
# ['balkon', 'gaz', 'woda', 'kanalizacja', 'piwnica', 'internet']
# ['balkon', 'woda', 'kanalizacja', 'internet']
# []
# []
# []
# []
# ['balkon', 'winda', 'piwnica']
# ['balkon', 'winda', 'miejsce parkingowe']
# ['ogródek', 'piwnica']
# ['balkon', 'garaż', 'winda', 'miejsce parkingowe']
# ['balkon', 'miejsce parkingowe']
# []
# ['balkon', 'piwnica', 'internet']
# []
# Page number: 29
# <Response [200]>
# 30
# ['balkon', 'winda']
# ['balkon', 'winda', 'miejsce parkingowe']
# ['balkon', 'winda', 'miejsce parkingowe']
# []
# ['balkon', 'garaż', 'ogródek', 'gaz', 'woda', 'kanalizacja', 'siła', 'piwnica', 'miejsce parkingowe', 'internet', 'kuchnia', 'aneks kuchenny', 'kablówka', 'komórka lokatorska', 'rowerownia']
# ['balkon', 'piwnica', 'internet', 'kablówka', 'światłowód']
# []
# []
# ['balkon', 'gaz', 'woda', 'kanalizacja', 'siła', 'piwnica', 'miejsce parkingowe', 'internet', 'kuchnia', 'kablówka', 'światłowód', 'komórka lokatorska']
# ['balkon', 'winda', 'woda', 'kanalizacja', 'piwnica', 'internet']
# ['woda', 'kanalizacja', 'siła', 'internet', 'kuchnia', 'aneks kuchenny', 'kablówka', 'osiedle zamknięte']
# ['balkon', 'winda', 'gaz', 'woda', 'kanalizacja', 'piwnica', 'kuchnia', 'komórka lokatorska']
# ['balkon', 'winda', 'miejsce parkingowe']
# ['balkon', 'gaz', 'woda', 'kanalizacja', 'siła', 'piwnica', 'miejsce parkingowe', 'internet', 'kuchnia', 'kablówka', 'światłowód', 'rowerownia']
# ['winda']
# ['balkon', 'gaz', 'woda', 'piwnica', 'miejsce parkingowe']
# ['balkon', 'winda', 'woda', 'piwnica', 'miejsce parkingowe', 'internet']
# []
# ['balkon', 'winda', 'miejsce parkingowe']
# ['balkon', 'garaż', 'ogródek', 'piwnica', 'miejsce parkingowe']
# ['balkon', 'piwnica']
# ['gaz', 'woda', 'kanalizacja', 'piwnica', 'miejsce parkingowe']
# ['balkon', 'winda', 'gaz', 'woda', 'kanalizacja', 'miejsce parkingowe', 'internet']
# ['balkon', 'winda', 'piwnica', 'miejsce parkingowe', 'aneks kuchenny', 'rowerownia']
# ['balkon', 'garaż', 'winda', 'piwnica', 'miejsce parkingowe', 'internet', 'kuchnia', 'aneks kuchenny', 'kablówka', 'światłowód', 'ochrona', 'komórka lokatorska', 'rowerownia', 'osiedle zamknięte']
# ['balkon', 'gaz', 'woda', 'kanalizacja', 'siła', 'internet', 'aneks kuchenny', 'kablówka', 'światłowód']
# ['balkon', 'winda', 'gaz', 'woda', 'kanalizacja', 'piwnica', 'miejsce parkingowe', 'internet', 'kuchnia', 'kablówka']
# []
# ['balkon', 'winda', 'gaz', 'woda', 'kanalizacja', 'miejsce parkingowe', 'internet']
# ['balkon', 'piwnica', 'miejsce parkingowe', 'internet', 'aneks kuchenny', 'kablówka', 'światłowód']
# Page number: 30
# <Response [200]>
# 30
# ['balkon', 'winda', 'gaz', 'woda', 'kanalizacja', 'piwnica', 'internet']
# []
# ['balkon', 'winda']
# ['balkon', 'winda', 'miejsce parkingowe']
# ['garaż', 'ogródek', 'gaz', 'woda', 'kanalizacja', 'piwnica', 'miejsce parkingowe', 'internet']
# ['winda']
# ['balkon', 'winda', 'miejsce parkingowe']
# []
# ['balkon', 'winda', 'miejsce parkingowe']
# ['balkon', 'winda', 'gaz', 'woda', 'kanalizacja', 'piwnica', 'internet']
# ['winda', 'ogródek', 'piwnica', 'miejsce parkingowe', 'internet']
# []
# []
# ['miejsce parkingowe']
# ['balkon', 'garaż', 'winda', 'loggia', 'woda', 'kanalizacja', 'siła', 'miejsce parkingowe', 'internet', 'kuchnia', 'aneks kuchenny', 'kablówka', 'światłowód', 'ochrona', 'osiedle zamknięte']
# []
# ['garaż', 'winda', 'piwnica', 'miejsce parkingowe']
# ['balkon', 'gaz', 'piwnica', 'internet', 'kablówka', 'światłowód', 'rowerownia']
# ['gaz', 'piwnica', 'miejsce parkingowe']
# ['winda']
# ['balkon', 'winda', 'miejsce parkingowe', 'kuchnia']
# ['balkon', 'gaz', 'woda', 'kanalizacja', 'piwnica', 'miejsce parkingowe', 'internet']
# ['garaż', 'ogródek', 'gaz', 'woda', 'kanalizacja', 'piwnica', 'miejsce parkingowe', 'internet']
# ['balkon', 'gaz', 'woda', 'kanalizacja', 'piwnica']
# ['balkon', 'winda', 'miejsce parkingowe']
# ['balkon', 'winda', 'miejsce parkingowe']
# ['ogródek', 'gaz', 'woda', 'kanalizacja', 'piwnica', 'miejsce parkingowe']
# ['balkon', 'garaż', 'winda', 'aneks kuchenny']
# ['balkon', 'winda', 'piwnica']
# ['balkon', 'winda', 'miejsce parkingowe']
# Page number: 31
# <Response [200]>
# 30
# []
# ['balkon', 'woda', 'kanalizacja', 'internet']
# []
# ...
# []
# []
# []
# ['balkon', 'woda', 'piwnica', 'internet']
# ['balkon', 'woda', 'kanalizacja', 'piwnica', 'internet']
# ['balkon', 'gaz', 'woda', 'miejsce parkingowe']
# ['balkon', 'piwnica']
# ['winda', 'piwnica', 'miejsce parkingowe']
# ['garaż', 'ogródek', 'gaz', 'woda', 'kanalizacja', 'piwnica', 'miejsce parkingowe']
# ['winda', 'ogródek', 'piwnica', 'miejsce parkingowe']
# ['balkon', 'winda', 'piwnica', 'miejsce parkingowe', 'internet', 'kuchnia']
# []
# []
# ['balkon', 'winda', 'woda', 'kanalizacja', 'miejsce parkingowe', 'internet']
# ['kuchnia']
# ['balkon', 'kuchnia']
# ['balkon', 'winda', 'gaz', 'woda', 'kanalizacja', 'miejsce parkingowe', 'internet']
# ['ogródek']
# ['winda', 'woda', 'internet']
# ['balkon', 'piwnica']
# Page number: 139
# <Response [200]>
# 30
# ['balkon', 'piwnica']
# ['balkon', 'ogródek', 'piwnica', 'miejsce parkingowe']
# ['balkon', 'garaż', 'miejsce parkingowe']
# []
# ['gaz', 'woda', 'kanalizacja', 'internet', 'kuchnia']
# ['gaz', 'woda', 'kanalizacja', 'piwnica', 'miejsce parkingowe', 'internet']
# ['gaz', 'woda', 'kanalizacja', 'piwnica', 'miejsce parkingowe', 'internet']
# ['balkon', 'piwnica']
# ['winda', 'miejsce parkingowe']
# ['balkon', 'miejsce parkingowe']
# ['piwnica']
# ['garaż', 'winda', 'aneks kuchenny']
# ['garaż', 'ogródek', 'miejsce parkingowe']
# ['gaz', 'woda']
# ['balkon', 'ogródek', 'gaz', 'woda', 'kanalizacja', 'piwnica', 'miejsce parkingowe']
# ['garaż', 'winda', 'aneks kuchenny']
# ['garaż', 'kuchnia']
# ['aneks kuchenny']
# []
# ['woda', 'kanalizacja', 'piwnica', 'internet']
# ['piwnica', 'miejsce parkingowe']
# ['winda', 'miejsce parkingowe', 'internet', 'kuchnia']
# ['winda', 'ogródek', 'woda', 'kanalizacja', 'miejsce parkingowe', 'internet']
# ['garaż', 'gaz', 'woda', 'kanalizacja', 'miejsce parkingowe', 'internet', 'kuchnia']
# ['balkon', 'dwupoziomowe']
# ['balkon']
# []
# []
# ['winda']
# ['balkon', 'garaż', 'winda', 'aneks kuchenny']
# Page number: 140
# <Response [200]>
# 30
# ['garaż', 'taras', 'ogródek', 'gaz', 'woda', 'kanalizacja', 'siła', 'piwnica', 'miejsce parkingowe', 'internet', 'aneks kuchenny', 'kablówka', 'światłowód']
# ['garaż', 'winda', 'miejsce parkingowe', 'internet', 'kuchnia']
# ['balkon', 'garaż', 'ogródek', 'miejsce parkingowe']
# ['ogródek', 'piwnica']
# ['balkon', 'piwnica']
# ['winda', 'kuchnia']
# ['balkon', 'woda', 'kanalizacja', 'miejsce parkingowe', 'internet', 'dwupoziomowe']
# ['balkon', 'woda', 'kanalizacja', 'internet']
# ['balkon', 'winda', 'woda', 'kanalizacja', 'miejsce parkingowe', 'internet']
# ['balkon', 'miejsce parkingowe']
# ['garaż', 'piwnica', 'miejsce parkingowe']
# []
# []
# ['garaż', 'miejsce parkingowe']
# []
# []
# ['winda', 'miejsce parkingowe', 'dwupoziomowe']
# ['garaż', 'taras', 'piwnica', 'miejsce parkingowe', 'internet', 'kuchnia']
# ['garaż', 'piwnica', 'miejsce parkingowe', 'internet', 'kuchnia']
# ['balkon', 'garaż', 'winda', 'ogródek', 'gaz', 'woda', 'kanalizacja', 'piwnica', 'miejsce parkingowe', 'internet']
# ['balkon', 'garaż', 'winda', 'woda', 'kanalizacja', 'miejsce parkingowe', 'internet']
# ['balkon', 'piwnica', 'miejsce parkingowe', 'dwupoziomowe']
# ['balkon', 'garaż', 'winda', 'woda', 'kanalizacja', 'miejsce parkingowe', 'internet']
# []
# ['balkon', 'winda', 'woda', 'kanalizacja', 'siła', 'piwnica', 'miejsce parkingowe', 'internet', 'aneks kuchenny', 'kablówka', 'światłowód']
# ['balkon', 'piwnica', 'miejsce parkingowe', 'internet', 'kuchnia']
# ['balkon', 'winda', 'gaz', 'woda', 'kanalizacja', 'piwnica', 'miejsce parkingowe', 'kuchnia']
# ['piwnica']
# ['balkon', 'winda', 'gaz', 'woda', 'kanalizacja', 'piwnica', 'miejsce parkingowe']
# ['winda', 'ogródek', 'woda', 'kanalizacja', 'miejsce parkingowe', 'internet']
# Page number: 141
# <Response [200]>
# 30
# ['balkon', 'winda', 'gaz', 'woda', 'kanalizacja', 'piwnica', 'miejsce parkingowe']
# ['winda']
# ['balkon']
# ['piwnica', 'kuchnia']
# ['balkon', 'garaż', 'winda', 'aneks kuchenny']
# []
# ['siła', 'piwnica', 'internet', 'kuchnia']
# ['aneks kuchenny']
# ['balkon', 'piwnica']
# ['ogródek', 'piwnica']
# ['garaż', 'taras', 'gaz', 'siła']
# ['balkon', 'winda', 'gaz', 'woda', 'kanalizacja', 'piwnica']
# ['balkon', 'winda', 'piwnica', 'miejsce parkingowe', 'internet', 'kuchnia']
# ['garaż', 'kuchnia']
# ['winda', 'piwnica']
# []
# ['balkon', 'piwnica', 'miejsce parkingowe']
# ['winda']
# ['balkon', 'woda', 'piwnica', 'internet']
# ['garaż', 'woda', 'kanalizacja', 'miejsce parkingowe', 'internet']
# ['balkon', 'gaz', 'woda', 'kanalizacja', 'miejsce parkingowe']
# []
# ['garaż', 'gaz', 'woda', 'kanalizacja', 'miejsce parkingowe', 'internet']
# ['balkon', 'winda', 'woda', 'kanalizacja', 'miejsce parkingowe', 'internet']
# ['kuchnia']
# ['balkon', 'miejsce parkingowe']
# ['balkon', 'piwnica']
# ['garaż', 'miejsce parkingowe', 'internet']
# ['garaż', 'winda', 'aneks kuchenny']
# ['balkon', 'garaż', 'gaz', 'siła', 'piwnica', 'internet']
# Page number: 142
# <Response [200]>
# 30
# ['balkon', 'winda', 'gaz', 'woda', 'kanalizacja', 'miejsce parkingowe', 'internet']
# ['winda', 'taras', 'ogródek', 'woda', 'kanalizacja', 'miejsce parkingowe', 'internet', 'kuchnia', 'aneks kuchenny', 'rowerownia']
# ['winda', 'ogródek', 'miejsce parkingowe']
# ['ogródek', 'piwnica', 'miejsce parkingowe', 'internet', 'kuchnia', 'kablówka', 'osiedle zamknięte']
# ['balkon', 'winda', 'woda', 'kanalizacja', 'miejsce parkingowe', 'internet']
# ['woda', 'kanalizacja', 'internet']
# ['balkon']
# ['ogródek', 'miejsce parkingowe']
# []
# ['balkon', 'woda', 'kanalizacja', 'piwnica', 'miejsce parkingowe', 'internet']
# []
# ['piwnica']
# ['balkon', 'piwnica', 'miejsce parkingowe', 'internet', 'kuchnia']
# ['balkon', 'winda', 'piwnica', 'aneks kuchenny', 'kablówka']
# ['winda', 'taras', 'internet', 'aneks kuchenny', 'kablówka']
# ['balkon', 'garaż', 'piwnica', 'internet', 'kablówka']
# ['balkon', 'garaż', 'winda', 'piwnica', 'internet', 'kablówka']
# ['balkon', 'garaż', 'winda', 'piwnica', 'internet', 'kablówka']
# ['balkon', 'internet', 'aneks kuchenny', 'kablówka']
# ['winda', 'woda', 'kanalizacja', 'miejsce parkingowe']
# ['winda', 'woda', 'kanalizacja', 'miejsce parkingowe']
# ['aneks kuchenny']
# ['balkon', 'gaz', 'woda', 'kanalizacja', 'miejsce parkingowe', 'internet', 'dwupoziomowe']
# []
# ['balkon', 'garaż', 'winda', 'piwnica', 'miejsce parkingowe', 'internet', 'kuchnia']
# ['miejsce parkingowe']
# ['balkon', 'ogródek', 'miejsce parkingowe', 'internet']
# ['balkon', 'garaż', 'ogródek', 'miejsce parkingowe']
# ['garaż', 'winda', 'piwnica', 'miejsce parkingowe']
# ['balkon', 'garaż', 'piwnica', 'miejsce parkingowe', 'kuchnia']
# Page number: 143
# <Response [200]>
# 30
# ['balkon', 'garaż', 'winda', 'piwnica']
# ['balkon', 'garaż', 'taras', 'ogródek', 'gaz', 'woda', 'kanalizacja', 'siła', 'piwnica', 'miejsce parkingowe', 'internet', 'kuchnia', 'aneks kuchenny', 'dwupoziomowe', 'kablówka', 'światłowód']
# ['ogródek', 'miejsce parkingowe']
# ['garaż', 'piwnica', 'miejsce parkingowe']
# ['winda', 'woda', 'piwnica', 'internet']
# []
# ['balkon']
# ['winda', 'ogródek', 'woda', 'kanalizacja', 'miejsce parkingowe', 'internet']
# ['winda', 'gaz', 'woda', 'kanalizacja', 'piwnica', 'miejsce parkingowe', 'internet', 'kuchnia', 'kablówka', 'komórka lokatorska']
# []
# ['piwnica', 'miejsce parkingowe']
# []
# ['balkon', 'piwnica', 'miejsce parkingowe']
# ['garaż', 'ogródek', 'gaz', 'woda', 'kanalizacja', 'piwnica', 'miejsce parkingowe', 'internet']
# ['garaż', 'miejsce parkingowe', 'internet']
# ['balkon', 'winda', 'miejsce parkingowe']
# ['balkon', 'garaż']
# ['balkon', 'gaz', 'woda', 'kanalizacja', 'piwnica', 'kuchnia']
# ['garaż', 'woda', 'piwnica', 'kuchnia']
# ['balkon', 'miejsce parkingowe']
# ['miejsce parkingowe']
# ['kuchnia']
# ['balkon', 'winda', 'woda', 'kanalizacja', 'miejsce parkingowe', 'internet']
# ['garaż', 'piwnica', 'miejsce parkingowe']
# ['balkon', 'winda', 'miejsce parkingowe', 'aneks kuchenny', 'komórka lokatorska', 'osiedle zamknięte']
# ['piwnica', 'miejsce parkingowe']
# []
# []
# ['balkon', 'winda', 'miejsce parkingowe']
# []
# Page number: 144
# <Response [200]>
# 30
# ['internet']
# []
# ['piwnica', 'miejsce parkingowe', 'internet', 'kuchnia']
# ['garaż', 'ogródek', 'piwnica', 'miejsce parkingowe']
# ['balkon', 'ogródek', 'piwnica', 'miejsce parkingowe']
# ['gaz', 'woda', 'kanalizacja', 'internet', 'kuchnia']
# ['balkon', 'piwnica', 'miejsce parkingowe', 'internet', 'kuchnia']
# ['balkon', 'winda', 'woda', 'kanalizacja', 'miejsce parkingowe', 'internet']
# ['garaż', 'taras', 'piwnica', 'miejsce parkingowe', 'internet', 'kuchnia']
# ['balkon', 'miejsce parkingowe']
# ['piwnica', 'internet']
# ['balkon', 'winda', 'internet', 'kuchnia']
# ['balkon', 'winda', 'woda', 'miejsce parkingowe', 'internet', 'kuchnia', 'kablówka', 'światłowód', 'komórka lokatorska']
# []
# []
# ['balkon', 'ogródek', 'gaz', 'woda', 'kanalizacja', 'piwnica', 'miejsce parkingowe', 'internet']
# ['garaż', 'taras', 'gaz', 'siła']
# ['garaż', 'aneks kuchenny']
# ['piwnica', 'internet']
# ['balkon', 'garaż', 'ogródek', 'miejsce parkingowe']
# []
# ['kuchnia']
# ['balkon', 'woda', 'kanalizacja', 'piwnica', 'internet']
# ['balkon', 'ogródek', 'gaz', 'woda', 'miejsce parkingowe', 'internet']
# ['balkon']
# ['balkon', 'piwnica', 'miejsce parkingowe', 'internet', 'kuchnia']
# ['balkon', 'garaż', 'winda', 'woda', 'miejsce parkingowe', 'internet']
# ['kuchnia']
# ['piwnica', 'miejsce parkingowe']
# ['balkon', 'piwnica', 'miejsce parkingowe']
# Page number: 145
# <Response [200]>
# 30
# []
# ['ogródek', 'woda', 'kanalizacja', 'piwnica', 'miejsce parkingowe', 'internet']
# ['winda', 'woda', 'kanalizacja', 'miejsce parkingowe']
# ['balkon', 'garaż', 'ogródek', 'miejsce parkingowe']
# ['balkon', 'garaż', 'ogródek', 'piwnica', 'miejsce parkingowe']
# ['balkon']
# ['balkon', 'piwnica']
# ['balkon', 'winda', 'piwnica', 'miejsce parkingowe', 'internet', 'kuchnia']
# ['balkon', 'winda', 'gaz', 'woda', 'kanalizacja', 'miejsce parkingowe', 'internet']
# ['piwnica', 'miejsce parkingowe', 'internet', 'kuchnia']
# ['winda', 'woda', 'kanalizacja', 'miejsce parkingowe']
# ['balkon', 'piwnica']
# ['balkon', 'garaż', 'woda', 'kanalizacja', 'miejsce parkingowe', 'internet']
# ['siła', 'miejsce parkingowe']
# []
# []
# ['piwnica', 'miejsce parkingowe', 'internet', 'kuchnia']
# ['winda']
# ['balkon', 'gaz', 'woda', 'kanalizacja', 'internet']
# ['winda', 'gaz', 'woda', 'piwnica', 'miejsce parkingowe', 'internet']
# ['balkon', 'garaż', 'piwnica', 'miejsce parkingowe']
# ['winda', 'ogródek', 'miejsce parkingowe']
# ['ogródek', 'gaz', 'woda', 'kanalizacja', 'miejsce parkingowe', 'internet']
# ['balkon', 'garaż', 'winda', 'miejsce parkingowe']
# ['balkon', 'ogródek', 'piwnica']
# ['winda', 'woda', 'kanalizacja', 'miejsce parkingowe', 'internet']
# ['balkon', 'piwnica', 'miejsce parkingowe', 'internet', 'kuchnia']
# ['winda']
# []
# ['balkon', 'garaż', 'woda', 'kanalizacja', 'miejsce parkingowe', 'internet']
# Page number: 146
# <Response [200]>
# 30
# []
# ['garaż', 'taras', 'kuchnia']
# ['balkon', 'garaż', 'gaz', 'woda', 'kanalizacja', 'piwnica', 'miejsce parkingowe']
# ['garaż', 'ogródek', 'piwnica', 'miejsce parkingowe']
# ['gaz', 'woda', 'miejsce parkingowe', 'internet']
# []
# ['balkon', 'winda', 'piwnica', 'miejsce parkingowe']
# ['winda', 'woda', 'kanalizacja', 'miejsce parkingowe', 'internet']
# ['ogródek', 'miejsce parkingowe']
# ['woda', 'kanalizacja', 'piwnica', 'internet']
# ['winda', 'miejsce parkingowe']
# ['balkon', 'woda', 'kanalizacja', 'piwnica', 'miejsce parkingowe', 'internet', 'aneks kuchenny', 'kablówka']
# []
# []
# ['winda', 'piwnica']
# []
# ['balkon', 'garaż', 'piwnica', 'miejsce parkingowe']
# []
# ['woda', 'kanalizacja', 'miejsce parkingowe', 'internet']
# ['piwnica', 'miejsce parkingowe']
# ['balkon', 'winda', 'woda', 'kanalizacja', 'miejsce parkingowe', 'internet']
# ['balkon', 'miejsce parkingowe']
# ['balkon', 'garaż', 'ogródek', 'gaz', 'woda', 'kanalizacja', 'miejsce parkingowe', 'internet']
# []
# ['balkon']
# ['balkon', 'winda']
# ['balkon', 'ogródek', 'gaz', 'woda', 'piwnica', 'miejsce parkingowe', 'internet']
# ['balkon', 'garaż', 'piwnica', 'miejsce parkingowe', 'internet', 'kuchnia']
# ['balkon', 'garaż', 'winda', 'miejsce parkingowe', 'internet', 'kuchnia']
# []
# Page number: 147
# <Response [200]>
# 30
# ['garaż', 'ogródek', 'gaz', 'woda', 'kanalizacja', 'siła', 'piwnica', 'miejsce parkingowe', 'kuchnia', 'dwupoziomowe', 'światłowód', 'komórka lokatorska']
# ['miejsce parkingowe']
# ['winda', 'gaz', 'woda', 'kanalizacja', 'piwnica', 'internet']
# ['balkon', 'piwnica', 'internet', 'kuchnia']
# ['balkon', 'garaż', 'ogródek', 'gaz', 'woda', 'kanalizacja', 'piwnica', 'miejsce parkingowe']
# ['balkon', 'piwnica']
# ['garaż', 'ogródek', 'piwnica', 'miejsce parkingowe']
# ['balkon', 'winda', 'woda', 'kanalizacja', 'miejsce parkingowe', 'internet']
# ['garaż', 'winda', 'aneks kuchenny']
# ['balkon', 'garaż', 'winda', 'woda', 'miejsce parkingowe', 'internet']
# ['balkon', 'piwnica']
# []
# ['balkon', 'winda', 'gaz', 'woda', 'kanalizacja', 'internet']
# ['ogródek', 'gaz', 'woda', 'kanalizacja', 'siła', 'miejsce parkingowe', 'internet', 'kuchnia', 'aneks kuchenny', 'dwupoziomowe', 'światłowód', 'ochrona']
# ['winda', 'piwnica', 'miejsce parkingowe', 'internet', 'kuchnia']
# ['garaż', 'winda', 'taras', 'miejsce parkingowe', 'kuchnia']
# ['piwnica', 'kuchnia']
# ['balkon', 'piwnica']
# ['balkon', 'miejsce parkingowe']
# ['balkon', 'woda', 'kanalizacja', 'miejsce parkingowe']
# ['balkon', 'gaz', 'woda', 'kanalizacja', 'piwnica', 'internet']
# ['garaż', 'taras', 'ogródek', 'woda', 'kanalizacja', 'piwnica', 'miejsce parkingowe', 'internet', 'kablówka']
# ['balkon', 'gaz', 'woda', 'kanalizacja', 'piwnica', 'kuchnia']
# ['woda', 'kanalizacja', 'piwnica', 'internet']
# ['winda', 'woda', 'kanalizacja', 'miejsce parkingowe', 'internet']
# ['garaż', 'ogródek', 'gaz', 'woda', 'kanalizacja', 'piwnica', 'miejsce parkingowe', 'internet']
# ['internet']
# ['miejsce parkingowe']
# ['garaż', 'winda', 'taras', 'internet', 'kuchnia']
# ['balkon', 'winda', 'miejsce parkingowe']
# Page number: 148
# <Response [200]>
# 30
# []
# ['balkon']
# ['balkon', 'ogródek', 'piwnica', 'miejsce parkingowe']
# ['balkon', 'piwnica', 'miejsce parkingowe', 'kuchnia']
# ['balkon', 'garaż', 'piwnica', 'miejsce parkingowe', 'internet']
# ['balkon', 'garaż', 'gaz', 'siła', 'piwnica', 'miejsce parkingowe', 'internet']
# ['siła', 'piwnica', 'internet', 'kuchnia']
# ['woda', 'kanalizacja', 'internet', 'kuchnia']
# ['garaż', 'winda', 'piwnica', 'miejsce parkingowe', 'internet', 'kuchnia']
# ['winda', 'ogródek', 'woda', 'kanalizacja', 'miejsce parkingowe', 'internet']
# ['balkon', 'ogródek', 'piwnica', 'miejsce parkingowe']
# ['balkon', 'ogródek', 'piwnica', 'miejsce parkingowe']
# []
# ['balkon', 'winda', 'piwnica', 'miejsce parkingowe', 'internet', 'kuchnia']
# []
# ['gaz', 'woda', 'kanalizacja', 'piwnica', 'internet']
# ['balkon', 'miejsce parkingowe']
# ['balkon', 'gaz', 'piwnica', 'miejsce parkingowe', 'kuchnia']
# ['garaż', 'ogródek', 'piwnica', 'miejsce parkingowe']
# []
# ['garaż', 'miejsce parkingowe']
# ['woda', 'kanalizacja', 'piwnica', 'miejsce parkingowe', 'internet']
# ['garaż', 'kuchnia']
# ['gaz', 'woda', 'piwnica', 'miejsce parkingowe', 'internet']
# []
# ['gaz', 'woda']
# ['balkon', 'piwnica', 'miejsce parkingowe']
# ['balkon', 'miejsce parkingowe']
# []
# ['woda', 'kanalizacja', 'piwnica', 'miejsce parkingowe', 'internet']
# Page number: 149
# <Response [200]>
# 30
# []
# []
# ['gaz', 'woda', 'piwnica']
# ['balkon', 'winda', 'miejsce parkingowe']
# ['balkon', 'winda', 'gaz', 'woda', 'kanalizacja', 'miejsce parkingowe', 'internet']
# ['balkon', 'gaz', 'woda', 'kanalizacja']
# ['winda', 'ogródek', 'miejsce parkingowe']
# []
# ['woda', 'kanalizacja', 'siła', 'piwnica', 'miejsce parkingowe', 'internet', 'kuchnia', 'aneks kuchenny', 'kablówka', 'światłowód', 'osiedle zamknięte']
# ['balkon', 'miejsce parkingowe']
# []
# ['balkon', 'garaż', 'ogródek', 'piwnica', 'miejsce parkingowe']
# ['balkon', 'piwnica', 'miejsce parkingowe', 'internet', 'kuchnia']
# ['balkon', 'winda', 'woda', 'kanalizacja', 'miejsce parkingowe', 'internet']
# ['garaż', 'piwnica', 'miejsce parkingowe', 'internet', 'kuchnia']
# ['balkon', 'piwnica', 'miejsce parkingowe']
# ['balkon', 'winda', 'woda', 'kanalizacja', 'miejsce parkingowe', 'internet']
# ['winda', 'woda', 'kanalizacja', 'miejsce parkingowe', 'internet']
# []
# ['balkon', 'winda', 'miejsce parkingowe']
# ['garaż', 'kuchnia']
# ['gaz', 'woda', 'kanalizacja', 'piwnica', 'internet']
# []
# []
# ['winda']
# []
# ['winda']
# ['balkon', 'kuchnia']
# ['balkon', 'gaz', 'woda', 'kanalizacja', 'piwnica', 'kuchnia']
# ['taras', 'gaz', 'woda', 'kanalizacja', 'internet', 'kuchnia']

# %% [markdown]
# # Gathering data for the primary market

# %%
# Searching data for primary market (rynek pierwotny)
url = urls['ogloszenia_pierwotny']


"""
Iterating through each page and gathering necessary data such as:
- title
- district
- area
- number of rooms
- year of creation
- price in PLN (for m2)
- link of individual adv (to dive further)

"""
for page in range(0,100):
    print("Page number: " + str(page))
    response = requests.get(url, params={'strona': f"{page}"})
    print(response)
    if response.ok :

        # Using previously defined function for taking data from a main page
        title_list, district_list, area_list, number_of_rooms_list, year_of_creation_list, price_list, href_list = take_data_from_main(response)

        print(len(title_list))

        # Iterating through lists to create separate records
        for element in range(len(title_list)):
            try:
              price = price_list[element].get_text().replace(" ", "").rstrip("zł/m2")
            except:
              continue
            tytul = title_list[element].get_text().strip().replace("=", "")
            powierzchnia = area_list[element].get_text().strip().rstrip(" m2")
            number_of_rooms = number_of_rooms_list[element].get_text().strip()
            year_of_creation = year_of_creation_list[element].get_text().strip()
            href = href_list[element]
            link = href['href']
            type_of_building, additional_list, floor = take_data_from_individual(link)

            #Converting a Set of values into a list of strings
            additional_list_str = []
            find_string = lambda x : 1 if x.lower() in additional_list_str else 0
            for item in range(len(additional_list)):
              additional_list_str.append(additional_list[item].get_text().strip().lower())

            # Using lambda function to check if an asset for a buyer is in the offer
            garage = find_string('Garaż')
            balcony = find_string('Balkon')
            internet = find_string('Internet')
            parking = find_string('Miejsce Parkingowe')
            elevator = find_string('Winda')
            terrace = find_string('Taras')
            basement = find_string('Piwnica')
            garden = find_string('Ogródek')

            # Creating a record for a specific offer and adding it to a list. To separate data from each other the '=' sign is being used
            record = f"{tytul}={district}={powierzchnia}={number_of_rooms}={year_of_creation}={price}={type_of_building}={garage}={balcony}={internet}={parking}={elevator}={floor}={terrace}={basement}={garden}=primary"
            data.append(record)
# Out:
# Page number: 0
# <Response [200]>
# 30
# Page number: 1
# <Response [200]>
# 30
# Page number: 2
# <Response [200]>
# 30
# Page number: 3
# <Response [200]>
# 30
# Page number: 4
# <Response [200]>
# 30
# Page number: 5
# <Response [200]>
# 30
# Page number: 6
# <Response [200]>
# 30
# Page number: 7
# <Response [200]>
# 30
# Page number: 8
# <Response [200]>
# 30
# Page number: 9
# <Response [200]>
# 30
# Page number: 10
# <Response [200]>
# 30
# Page number: 11
# <Response [200]>
# 30
# Page number: 12
# <Response [200]>
# 30
# Page number: 13
# <Response [200]>
# 30
# Page number: 14
# <Response [200]>
# 30
# Page number: 15
# <Response [200]>
# 30
# Page number: 16
# <Response [200]>
# 30
# Page number: 17
# <Response [200]>
# 30
# Page number: 18
# <Response [200]>
# 30
# Page number: 19
# <Response [200]>
# 30
# Page number: 20
# <Response [200]>
# 30
# Page number: 21
# <Response [200]>
# 30
# Page number: 22
# <Response [200]>
# 30
# Page number: 23
# <Response [200]>
# 30
# Page number: 24
# <Response [200]>
# 30
# Page number: 25
# <Response [200]>
# 30
# Page number: 26
# <Response [200]>
# 30
# Page number: 27
# <Response [200]>
# 30
# Page number: 28
# <Response [200]>
# 30
# Page number: 29
# <Response [200]>
# 30
# Page number: 30
# <Response [200]>
# 30
# Page number: 31
# <Response [200]>
# 30
# Page number: 32
# <Response [200]>
# 30
# Page number: 33
# <Response [200]>
# 30
# Page number: 34
# <Response [200]>
# 30
# Page number: 35
# <Response [200]>
# 30
# Page number: 36
# <Response [200]>
# 30
# Page number: 37
# <Response [200]>
# 30
# Page number: 38
# <Response [200]>
# 30
# Page number: 39
# <Response [200]>
# 30
# Page number: 40
# <Response [200]>
# 30
# Page number: 41
# <Response [200]>
# 30
# Page number: 42
# <Response [200]>
# 30
# Page number: 43
# <Response [200]>
# 30
# Page number: 44
# <Response [200]>
# 30
# Page number: 45
# <Response [200]>
# 30
# Page number: 46
# <Response [200]>
# 30
# Page number: 47
# <Response [200]>
# 30
# Page number: 48
# <Response [200]>
# 30
# Page number: 49
# <Response [200]>
# 30
# Page number: 50
# <Response [200]>
# 30
# Page number: 51
# <Response [200]>
# 30
# Page number: 52
# <Response [200]>
# 30
# Page number: 53
# <Response [200]>
# 30
# Page number: 54
# <Response [200]>
# 30
# Page number: 55
# <Response [200]>
# 30
# Page number: 56
# <Response [200]>
# 30
# Page number: 57
# <Response [200]>
# 30
# Page number: 58
# <Response [200]>
# 30
# Page number: 59
# <Response [200]>
# 30
# Page number: 60
# <Response [200]>
# 30
# Page number: 61
# <Response [200]>
# 30
# Page number: 62
# <Response [200]>
# 30
# Page number: 63
# <Response [200]>
# 30
# Page number: 64
# <Response [200]>
# 30
# Page number: 65
# <Response [200]>
# 30
# Page number: 66
# <Response [200]>
# 30
# Page number: 67
# <Response [200]>
# 30
# Page number: 68
# <Response [200]>
# 30
# Page number: 69
# <Response [200]>
# 30
# Page number: 70
# <Response [200]>
# 30
# Page number: 71
# <Response [200]>
# 30
# Page number: 72
# <Response [200]>
# 30
# Page number: 73
# <Response [200]>
# 30
# Page number: 74
# <Response [200]>
# 30
# Page number: 75
# <Response [200]>
# 30
# Page number: 76
# <Response [200]>
# 30
# Page number: 77
# <Response [200]>
# 30
# Page number: 78
# <Response [200]>
# 30
# Page number: 79
# <Response [200]>
# 30
# Page number: 80
# <Response [200]>
# 30
# Page number: 81
# <Response [200]>
# 30
# Page number: 82
# <Response [200]>
# 30
# Page number: 83
# <Response [200]>
# 30
# Page number: 84
# <Response [200]>
# 30
# Page number: 85
# <Response [200]>
# 30
# Page number: 86
# <Response [200]>
# 30
# Page number: 87
# <Response [200]>
# 30
# Page number: 88
# <Response [200]>
# 30
# Page number: 89
# <Response [200]>
# 30
# Page number: 90
# <Response [200]>
# 30
# Page number: 91
# <Response [200]>
# 30
# Page number: 92
# <Response [200]>
# 30
# Page number: 93
# <Response [200]>
# 30
# Page number: 94
# <Response [200]>
# 30
# Page number: 95
# <Response [200]>
# 30
# Page number: 96
# <Response [200]>
# 30
# Page number: 97
# <Response [200]>
# 30
# Page number: 98
# <Response [200]>
# 30
# Page number: 99
# <Response [200]>
# 30

# %%
df = pd.DataFrame(data)

# %%
print(df)
# Out:
#                                                       0
# 0     3 pok 71m2 loggia 6m2 widok na morze i LAS=Gda...
# 1     Parter | 2-pokoje | Gotowe do zamieszkania=Gda...
# 2     Mieszkanie 2-pokojowe Przymorze=Gdańsk Przymor...
# 3     3- pok.mieszkanie, kamerlane osiedle, nowe bud...
# 4     Mieszkania=Gdańsk Łostowice, Niepołomicka 20=4...
# ...                                                 ...
# 7433  Już jest! nowe i czeka=Gdańsk Łostowice, Wielk...
# 7434  Mieszkanie - Gdańsk Łostowice=Gdańsk Łostowice...
# 7435  Blisko morza/81,4 m2/strefa fitness=Gdańsk Brz...
# 7436  2 pokoje, inwestycyjnie?!=Gdańsk Łostowice, Wi...
# 7437  Nowe i gotowe=Gdańsk Łostowice, Wielkopolska=4...
#
# [7438 rows x 1 columns]

# %%
columns = ["title", "district", "area", "number_of_rooms", "year_of_creation", 'price_for_m2_in_PLN', 'type_of_building', 'garage', 'balcony', 'internet', 'parking', 'elevator', 'floor', 'terrace', 'basement', 'garden','type_of_market']
correct_df = df[columns] = df[0].str.split('=', expand=True)

# %%
print(df.dtypes)
correct_df.columns = columns
display(correct_df)
# Out:
# 0    object
# dtype: object
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-8d5098545bbc> in <cell line: 2>()
#       1 print(df.dtypes)
# ----> 2 correct_df.columns = columns
#       3 display(correct_df)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __setattr__(self, name, value)
#    6000         try:
#    6001             object.__getattribute__(self, name)
# -> 6002             return object.__setattr__(self, name, value)
#    6003         except AttributeError:
#    6004             pass
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in _set_axis(self, axis, labels)
#     728         """
#     729         labels = ensure_index(labels)
# --> 730         self._mgr.set_axis(axis, labels)
#     731         self._clear_item_cache()
#     732
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/managers.py in set_axis(self, axis, new_labels)
#     223     def set_axis(self, axis: AxisInt, new_labels: Index) -> None:
#     224         # Caller is responsible for ensuring we have an Index object.
# --> 225         self._validate_set_axis(axis, new_labels)
#     226         self.axes[axis] = new_labels
#     227
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/base.py in _validate_set_axis(self, axis, new_labels)
#      68
#      69         elif new_len != old_len:
# ---> 70             raise ValueError(
#      71                 f"Length mismatch: Expected axis has {old_len} elements, new "
#      72                 f"values have {new_len} elements"
#
# ValueError: Length mismatch: Expected axis has 18 elements, new values have 17 elements

# %%
correct_df['area'].replace('\s+$', '', regex=True, inplace=True)
correct_df[['area', 'price_for_m2_in_PLN']] = correct_df[['area', 'price_for_m2_in_PLN']].astype(float)
correct_df[['number_of_rooms', 'year_of_creation']] = correct_df[['number_of_rooms', 'year_of_creation']].astype(int)
correct_df[['garage', 'balcony', 'internet', 'parking', 'elevator', 'terrace', 'basement', 'garden']] = correct_df[['garage', 'balcony', 'internet', 'parking', 'elevator', 'terrace', 'basement', 'garden']].astype(int)
correct_df[['garage', 'balcony', 'internet', 'parking', 'elevator', 'terrace', 'basement', 'garden']] = correct_df[['garage', 'balcony', 'internet', 'parking', 'elevator', 'terrace', 'basement', 'garden']].astype(bool)
correct_df['floor'].replace('nan', np.nan, inplace = True)
correct_df['floor'].replace("Parter", "0", inplace = True)
print(correct_df.dtypes)

# %%
correct_df[correct_df['type_of_market'] == 'secondary']
# Out:
#                                                 title  \
# 0        2 pok oddzielna kuchnia cicha część Starówki
# 1   Piękna kamienica | Cicha okolica | Widok na zi...
# 2                         2-pokojowe mieszkanie Zaspa
# 3                         Okazja cenowa! inwestycyjne
# 4   Na sprzedaż mieszkanie 4-pokojowe Gdańsk Wrzeszcz
# 5   Dni otwarte 17.04 duży ogródek || 20 min do morza
# 6        Unikalny i funkcjonalny apartament w Sopocie
# 7       Ekskluzywny Apartament 3-pokoje, blisko plaży
# 8   Promocja I Nowo Urządzone| 3 Pokoje|Nowoczesne...
# 9        Słoneczne mieszkanie na sprzedaż- Diamentowa
# 10   3 pokoje | Miejsce Parkingowe | 6min do tramwaju
# 11         2 pokoje | 5 min tramwaj | morena / jasień
# 12  |Przestronne 3 pokoje | Blisko Centrum | Fitne...
# 13   Funkcjonalne 2 pokoje z osobną kuchnią - Centrum
# 14  Przestronne 3 pok. mieszkanie. Blisko do morza...
# 15    Sprzedam bezpośrednio. 3 pok. Generalny remont.
# 16  Sprzedam bezpośrednio. 2 pok. Generalny remont...
# 17  Sprzedam bezpośrednio. 3 pok. Generalny remont...
# 18            Przestronne | balkon | nowe budownictwo
# 19               Trzy pokojowe mieszkanie blisko lasu
# 20  3-pokojowe, salon z aneksem, dwupoziomowe, got...
# 21   Projekt architekta* Umeblowane*Balkon+ 2xParking
# 22  Nowoczesny i komfortowy apartament 10 min od p...
# 23                      Brabank mieszkanie z balkonem
# 24                 Baltiq Plaza apartament z balkonem
# 25          Mieszkanie 2 pokoje  z balkonem Ujeścisko
# 26      Kawalerka z widokiem na morze w centrum Gdyni
# 27                             Chełm, Szpora 2 pokoje
# 28     Piękny, nowy dom jednorodzinny z dużym ogrodem
# 29        Śródmieście 2 pokoje w świetnej lokalizacji
#
#                                              district    area  \
# 0                                  Gdańsk Śródmieście   40.00
# 1                  Gdańsk Wrzeszcz, Adama Mickiewicza   96.60
# 2           Gdańsk Zaspa, Powstańców Wielkopolskich 5   53.19
# 3                  Gdańsk Długie Ogrody, Długa Grobla   42.59
# 4      Gdańsk Wrzeszcz, Bohaterów Getta Warszawskiego   74.53
# 5                            Gdańsk Letnica, Letnicka   56.05
# 6                      Sopot Dolny Sopot, Łokietka 19   14.00
# 7                        Gdańsk Letnica, Starowiejska   67.50
# 8                          Gdańsk Kokoszki, Nowatorów   66.70
# 9                        Gdańsk Orunia, Diamentowa 10   45.00
# 10                   Gdańsk Jasień, Lawendowe Wzgórze   59.00
# 11                            Gdańsk Jasień, Kartuska   45.50
# 12                    Gdańsk Siedlce, Andrzeja Struga   71.00
# 13                Gdańsk Stare Przedmieście, Toruńska   36.40
# 14                        Gdynia Pogórze, Staniewicza   63.00
# 15                           Gdynia Obłuże, Podgórska   47.00
# 16                         Gdynia Chylonia, Chylońska   37.00
# 17                         Gdynia Obłuże, Podgórska 7   47.00
# 18                         Gdańsk Łostowice, Hokejowa   48.87
# 19                       Gdynia Wielki Kack, Górnicza   69.60
# 20                  Gdańsk Zakoniczyn, Porębskiego 33   68.60
# 21                                  Sopot Górny Sopot   87.00
# 22                        Gdynia Mały Kack, Strzelców    5.00
# 23                 Gdańsk Śródmieście, Stara Stocznia   54.50
# 24                   Gdynia Śródmieście, Świętojańska   97.36
# 25                      Gdańsk Ujeścisko, Piotrkowska   46.00
# 26  Gdynia Wzgórze św. Maksymiliana, Cypriana Kami...   27.00
# 27              Gdańsk Chełm, Prof. Stanisława Szpora   44.49
# 28                    Gdańsk Św. Wojciech, Miłocińska  160.00
# 29                       Gdańsk Śródmieście, Kowalska   31.00
#
#     number_of_rooms  year_of_creation  price_for_m2_in_PLN  type_of_building  \
# 0                 2              1952              19975.0        Mieszkanie
# 1                 4              1910               9834.0        Mieszkanie
# 2                 2              2017              17823.0        Mieszkanie
# 3                 2              2017              18429.0        Mieszkanie
# 4                 4              1901              10466.0        Mieszkanie
# 5                 3              2023              14077.0        Mieszkanie
# 6                 6              2015              25345.0        Mieszkanie
# 7                 3              2023              16993.0        Mieszkanie
# 8                 3              2023              12429.0        Mieszkanie
# 9                 2              1970              12200.0        Mieszkanie
# 10                3              2016              11993.0        Mieszkanie
# 11                2              2011              13846.0        Mieszkanie
# 12                3              2022              16901.0        Mieszkanie
# 13                2              1969              14973.0        Mieszkanie
# 14                3              1985               1030.0        Mieszkanie
# 15                3              1980              11681.0        Mieszkanie
# 16                2              1975              12676.0        Mieszkanie
# 17                3              1975              11681.0        Mieszkanie
# 18                3              2023              12666.0        Mieszkanie
# 19                3              1996              10416.0        Mieszkanie
# 20                3              2005              10131.0        Mieszkanie
# 21                4              1910              19253.0        Mieszkanie
# 22                2              2012              15288.0        Mieszkanie
# 23                2              2020              31126.0        Mieszkanie
# 24                3              2015              29786.0        Mieszkanie
# 25                2              2000              12370.0        Mieszkanie
# 26                1              1980              21444.0        Mieszkanie
# 27                2              2010              13464.0        Mieszkanie
# 28                6              2009               8987.0  Dom wolnostojący
# 29                2              1952              18526.0        Mieszkanie
#
#     garage  balcony  internet  parking  elevator floor  terrace  basement  \
# 0    False     True     False    False     False     2    False      True
# 1    False    False      True    False     False     2    False      True
# 2    False    False      True     True      True     0    False     False
# 3    False    False      True     True      True     0     True     False
# 4    False    False     False    False     False     2    False     False
# 5     True    False     False    False      True     0    False     False
# 6     True     True      True     True      True     2     True      True
# 7    False    False     False    False     False     6    False     False
# 8    False    False     False    False     False     4    False     False
# 9    False     True      True     True     False     1    False     False
# 10   False     True      True     True      True     3    False      True
# 11   False     True      True     True      True     1    False      True
# 12   False     True      True     True      True     6    False      True
# 13   False    False     False    False      True     0    False     False
# 14   False     True      True    False     False     0    False      True
# 15   False    False      True    False     False     0    False      True
# 16   False    False      True    False      True     0    False      True
# 17   False     True      True    False      True    10    False      True
# 18    True    False     False    False     False     1    False     False
# 19    True     True     False     True     False     0    False      True
# 20   False     True      True     True     False     2    False     False
# 21   False    False     False    False     False     1    False     False
# 22   False    False     False    False     False     1    False     False
# 23   False     True     False     True      True     2    False     False
# 24   False     True     False     True      True     2    False     False
# 25   False     True     False    False     False     1    False      True
# 26   False     True     False    False      True     6    False     False
# 27   False     True     False    False     False     3    False      True
# 28    True    False     False     True     False   NaN    False     False
# 29   False    False     False    False     False     1    False     False
#
#     garden type_of_market
# 0    False      secondary
# 1    False      secondary
# 2     True      secondary
# 3    False      secondary
# 4    False      secondary
# 5    False      secondary
# 6    False      secondary
# 7    False      secondary
# 8    False      secondary
# 9    False      secondary
# 10   False      secondary
# 11   False      secondary
# 12   False      secondary
# 13   False      secondary
# 14   False      secondary
# 15   False      secondary
# 16   False      secondary
# 17   False      secondary
# 18   False      secondary
# 19    True      secondary
# 20   False      secondary
# 21   False      secondary
# 22   False      secondary
# 23   False      secondary
# 24   False      secondary
# 25   False      secondary
# 26   False      secondary
# 27   False      secondary
# 28    True      secondary
# 29   False      secondary

# %%
correct_df[correct_df['floor'].isna()]
# Out:
#                                                 title  \
# 28     Piękny, nowy dom jednorodzinny z dużym ogrodem
# 31  AMprojekt- Perspectum Gdańsk Jasień/Zabornia O...
# 40           Komfortowy dom w pięknej okolicy - Mondo
# 50  INPRO S.A. - OPTIMA - mieszkanie 3-pok. 61.71 ...
# 57  INPRO S.A. - Koncept -  Gotowe do odbioru mies...
# 63  Dom 257 m2 w Gdańsku ul. Kartuska, działka 647 m2
# 64                  Dom 184 m2 w Gdańsku ul. Kartuska
# 65  Dom 184 m2 w Gdańsku ul. Kartuska, działka 353 m2
# 70                                 Dom szeregowy - 7A
# 71                      Dom gotowy do wydania 5B ETAP
# 85  INPRO S.A. - OPTIMA - dom 4-pok. 110.18 m2 każ...
# 86  INPRO S.A. - OPTIMA - dom 4-pok. 110.18 m2 każ...
# 87           Komfortowy dom w pięknej okolicy - Mondo
#
#                                district    area  number_of_rooms  \
# 28      Gdańsk Św. Wojciech, Miłocińska  160.00                6
# 31               Gdańsk Jasień, Stolema  243.71                6
# 40             Gdańsk Morena, Jasieńska  216.00                6
# 50  Gdańsk Jasień, Tadeusza Jasińskiego   61.71                3
# 57                               Gdańsk   48.35                2
# 63                 Gdańsk, Kartuska 300  257.10                5
# 64                 Gdańsk, Kartuska 300  183.74                5
# 65                 Gdańsk, Kartuska 300  183.74                5
# 70     Gdynia Redłowo, Kombatantów 18/1  157.35                5
# 71  Gdańsk Matarnia - Rębiechowo, Ikara  113.66                4
# 85  Gdańsk Jasień, Tadeusza Jasińskiego  110.18                4
# 86  Gdańsk Jasień, Tadeusza Jasińskiego  110.18                4
# 87             Gdańsk Morena, Jasieńska  216.00                6
#
#     year_of_creation  price_for_m2_in_PLN  type_of_building  garage  balcony  \
# 28              2009               8987.0  Dom wolnostojący    True    False
# 31              2023               7911.0      Dom bliźniak    True     True
# 40              2024              11806.0      Dom bliźniak   False    False
# 50              2025              10476.0        Mieszkanie    True    False
# 57              2023              11340.0        Mieszkanie    True    False
# 63              2024                906.0     Dom szeregowy    True    False
# 64              2024               9960.0     Dom szeregowy    True    False
# 65              2024                107.0     Dom szeregowy    True    False
# 70              2024              15570.0     Dom szeregowy    True     True
# 71              2023               8578.0     Dom szeregowy    True     True
# 85              2024               8953.0  Dom wolnostojący    True    False
# 86              2024               9011.0  Dom wolnostojący    True    False
# 87              2024              12269.0      Dom bliźniak   False    False
#
#     internet  parking  elevator floor  terrace  basement  garden  \
# 28     False     True     False   NaN    False     False    True
# 31      True     True     False   NaN     True     False    True
# 40     False    False     False   NaN    False     False   False
# 50      True     True     False   NaN    False      True   False
# 57      True     True     False   NaN    False      True   False
# 63      True     True     False   NaN    False     False    True
# 64      True     True     False   NaN    False     False    True
# 65      True     True     False   NaN    False     False    True
# 70     False     True     False   NaN     True      True   False
# 71      True     True     False   NaN     True     False    True
# 85      True     True     False   NaN    False      True   False
# 86      True     True     False   NaN    False      True   False
# 87     False    False     False   NaN    False     False   False
#
#    type_of_market
# 28      secondary
# 31        primary
# 40        primary
# 50        primary
# 57        primary
# 63        primary
# 64        primary
# 65        primary
# 70        primary
# 71        primary
# 85        primary
# 86        primary
# 87        primary

# %%
correct_df.to_csv('estate_data.csv')

# %%
df_from_file = pd.read_csv('estate_data.csv')
display(df_from_file)

# %%
df_from_file[['district', 'street']] = df['district'].str.split(',', expand=True)
rows_without_space = df_from_file[~df_from_file['district'].str.contains(' ', regex=False)]
display(rows_without_space)
#display(df_from_file)
